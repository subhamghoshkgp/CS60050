# %% [markdown]
# # Programming Assignment 1

# %% [markdown]
# In this programming assignment, you will implement a linear regression model and a logistic regression model.
#
# In Part 1, you have to implement a linear regression model to predict the price of a house based on various input features.
#
# In Part 2, you have to implement a logistic regression model to predict the species of a grain using various morphological features.
#
# The assignment zip file (ML_Assignment_1.zip) contains 4 datasets which will be used in this assignment.
#
# You have to write your code in this jupyter notebook and submit the solved jupyter notebook with the file name \<Roll_No\>_A1.ipynb for evaluation. You have to enter your code only in those cells which are marked as ```## CODE REQUIRED ##```, and you have to write your code only between ```### START CODE HERE ###``` and ```### END CODE HERE ###``` comments.

# %% [markdown]
# ## Part 1: Linear Regression
#
# ### Problem Statement
# A real estate company is building a machine learning model to determine the price of a house. The model will take various information regarding a house as input features and predict the price per unit area. They decided to use the linear regression as the machine learning model. Your task is to help the company to build the model.
# Given various features of a house, you will create a linear regression model to predict the price of the house.
#
# ### Data Description
#
# **For Even Roll Number Students:**
#
# Dataset Filename: Taiwan_House.csv
#
# Attributes Information:
# 1. Transaction date
# 2. House age
# 3. Distance to the nearest MRT station
# 4. Number of convenience stores
# 5. Latitude
# 6. Longitude
#
# Target variable: house price of unit area
#
# **For Odd Roll Number Students:**
#
# Dataset Filename: Boston_House.csv
#
# Attributes Information:
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-­retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner­occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-­value property-­tax rate per $10,000
#
# 11. PTRATIO: pupil-­teacher ratio by town
# 12. B: 1000(Bk ­- 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
#
# Target Variable: MEDV: Median value of owner-­occupied homes in $1000's
#
#
# These are the following steps or functions that you have to complete to create and train the linear regression model:
# 1. Reading the data
# 2. Computing the loss function
# 3. Computing the gradient of the loss
# 4. Training the model using Batch Gradient Descent

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (2.0.1)Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
import math
import random

# %%
### 1.1. Reading the data

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Downloads\\ML_Assignment_1\\ML_Assignment_1'

# %% [markdown]
# In the following function ```load_data```, you have to read the data from the file and store the data into a pandas dataframe. Then you have to create two numpy arrays $X$ and $y$ from the dataframe:
#
# + $X$: Input data of the shape (number of samples, number of input features)
# + $y$: Target variable of the shape (number of samples,)

# %%
## CODE REQUIRED ##

def load_data(filepath):
    """
    This function loads the data into a pandas dataframe and coverts it into X and y numpy arrays

    Args:
        filepath: File path as a string
    Returns:
        X: Input data of the shape (# of samples, # of input features)
        y: Target variable of the shape (# of sample,)
    """

    ### START CODE HERE ###
    X= filepath.iloc[:,:-1].values #All rows and all columns except the last column
    y= filepath.iloc[:,-1].values #Only the last column is selected

    ### END CODE HERE ###

    return X,y

filepath = None
### START CODE HERE ###
## set the file path
import pandas as pd
filepath=pd.read_csv(r"C:\Users\HP\Downloads\ML_Assignment_1\ML_Assignment_1\Taiwan_House.csv")
### END CODE HERE ###
X, y = load_data(filepath)

print("Shape of X: ",X.shape, "Shape of y: ",y.shape)
# Out:
# Shape of X:  (414, 6) Shape of y:  (414,)

# %% [markdown]
# We will not use all the features from ```X```.
#
# **For Even Roll Number Students:**
# Set the last two digits of your roll number as the random seed and pick a number ``r`` between 3 and 6 (both inclusive) randomly. Use the first ```r``` features of the numpy array ```X```.
#
# **For Odd Roll Number Students:**
# Set the last two digits of your roll number as the random seed and pick a number ``r`` between 9 and 13 (both inclusive) randomly. Use the first ```r``` features of the numpy array ```X```.

# %%
## CODE REQUIRED ##

def random_feature_selection(X):
    """
    For Even Roll Number Students: Set the last two digits of your roll number as the random seed and pick a number r
    between 3 and 6 randomly. Use the first ```r``` features of the numpy array X.
    For Odd Roll Number Students: Set the last two digits of your roll number as the random seed and pick a number r
    between 9 and 13 randomly. Use the first ```r``` features of the numpy array X.
    Args:
        X: Input data of the shape (# of samples, # of input features)
    Returns:
        X_new: New input data of the shape (# of samples, r) containg only the first r features from X
    """

    X_new = None

    ### START CODE HERE ###
    np.random.seed(28) # My roll number is 22EE30028
    random_number=np.random.randint(3,7) # For even roll number students
    X_new = X[:,:random_number]



    ### END CODE HERE ###

    return X_new

X = random_feature_selection(X)
print("Shape of X: ",X.shape, "Shape of y: ",y.shape)
# Out:
# Shape of X:  (414, 4) Shape of y:  (414,)

# %% [markdown]
# We need to pre-process the data. We are using min-max scaler to scale the input data ($X$).
#
# After that, we split the data (```X``` and ```y```) into a training dataset (```X_train``` and ```y_train```) and test dataset (```X_test``` and ```y_test```).

# %%
## Data scaling and train-test split

def train_test_split(X, y, test_size=0.25, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    split_index = int(X.shape[0] * (1 - test_size))

    train_indices = indices[:split_index]
    test_indices = indices[split_index:]

    X_train = X[train_indices]
    X_test = X[test_indices]
    y_train = y[train_indices]
    y_test = y[test_indices]

    return X_train, X_test, y_train, y_test

def min_max_scaler(X, feature_range=(0, 1)):
    X_min = np.min(X, axis=0)
    X_max = np.max(X, axis=0)

    X_scaled = (X-X_min)/(X_max-X_min)

    return X_scaled


X = min_max_scaler(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print("Shape of X_train: ",X_train.shape, "Shape of y_train: ",y_train.shape)
print("Shape of X_test: ",X_test.shape, "Shape of y_test: ",y_test.shape)
# Out:
# Shape of X_train:  (310, 4) Shape of y_train:  (310,)
# Shape of X_test:  (104, 4) Shape of y_test:  (104,)

# %% [markdown]
# ### 1.2. Computing the Loss Function

# %% [markdown]
# In linear regression, the model parameters are:
#
# + $w$: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
#
# + $b$: Bias parameter (scalar) of the linear regression model
#
# Both $w$ and $b$ are numpy arrays.
#
# Given the model parameters $w$ and $b$, the prediction for an input sample $X^i$ is:
# $$h_{w,b}(X^i) = w \cdot X^i + b$$
# where $X^i$ is the $i^{th}$ training sample with shape (number of features,1)
#
# For linear regression, you have to implement and compute Mean Squarred Error loss fucntion:
# $$ L_{w,b}(X) = \sum_{i=1}^{m}(y^i - h_{w,b}(X^i))^2 $$
# where $y^i$ is the true target value for the $i^{th}$ sample and $h_{w,b}(X^i)$ is the predicted value for the $i^{th}$ sample using the parameters $w$ and $b$.
#
# $w$ is the list of parameters excluding the bias and $b$ is the bias term.

# %%
## CODE REQUIRED ##

def loss_function(X, y, w, b):
    """
    Computes the cost function for linear regression.

    Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        b: Bias parameter (scalar) of the linear regression model

    Returns
        loss: The loss function value of using w and b as the parameters to fit the data points in X and y
    """
    # number of training examples
    m = X.shape[0]

    ### START CODE HERE ###
    y_pred=np.dot(X,w.T)+ b
    errors=(y_pred.flatten()-y)**2
    loss=(1/(2*m))*np.sum(errors)


    ### END CODE HERE ###

    return loss

# %% [markdown]
# ### 1.3. Comptuing the Gradient of the Loss
#
# In this following function ```compute_gradient```, you have to compute the gradients $\frac{\partial L}{\partial w}$ and $\frac{\partial L}{\partial b}$ of the loss $L$ w.r.t. $w$ and $b$. More specifically, you have to iterate over every training example and compute the gradients of the loss for that training example. Finally, aggregate the gradient values for all the training examples and take the average. The gradients can be computed as:
# $$\frac{\partial L}{\partial w} = \frac{1}{m} \sum_{i=1}^m (h_{w,b}(X^i)-y^i)X^i$$
#
# $$\frac{\partial L}{\partial b} = \frac{1}{m} \sum_{i=1}^{m} (h_{w,b}(X^i)-y^i)$$

# %%
## CODE REQUIRED ##

def compute_gradient(X, y, w, b):
    """
    Computes the gradient values
    Args:
       X: Input data of the shape (# of training samples, # of input features)
       y: Target variable of the shape (# of training sample,)
       w: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
       b: Bias parameter of the linear regression model of the shape (1,1) or a scaler
    Returns:
       dL_dw : The gradient of the cost w.r.t. the parameters w with shape same as w
       dL_db : The gradient of the cost w.r.t. the parameter b with shape same as b
    """

    # Number of training examples
    m = X.shape[0]

    dL_dw = None
    dL_db = None

    ### START CODE HERE ###
    y_pred=np.dot(X,w.T)+b
    error=(y_pred.flatten()-y)
    dL_dw=(1/m)*np.dot(error.T,X)
    dL_db=(1/m)*np.sum(error)

    ### END CODE HERE ###
    return dL_dw, dL_db

# %% [markdown]
# ### 1.4. Training the Model using Batch Gradient Descent

# %% [markdown]
# Finally, you have to implement the batch gradient descent algorithm to train and learn the parameters of the linear regression model. You have to use ```loss_function``` and ```compute_gradient``` functions that you have implemented earlier in this assignment.
#
# In this ```batch_gradient_descent``` function, you have to compute the gradient for the training samples and update the parameters $w$ and $b$ in every iteration:
#
# + $w \leftarrow w - \alpha \frac{\partial L}{\partial w}$
#
# + $b \leftarrow b - \alpha \frac{\partial L}{\partial b}$
#
# Additionally, you have compute the loss function values in every iteration and store it in the list variable ```loss_hist``` and print the loss value after every 100 iterations during the training process.

# %%
## CODE REQUIRED ##

def batch_gradient_descent(X, y, w_initial, b_initial, alpha, num_iters):
    """
    Batch gradient descent to learn the parameters (w and b) of the linear regression model and to print loss values
    every 100 iterations

    Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w_initial: Initial parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        b_initial: Initial bias parameter (scalar) of the linear regression model
        alpha: Learning rate
        num_iters: number of iterations
    Returns
        w: Updated values of parameters of the model after training
        b: Updated bias of the model after training
        loss_hist: List of loss values for every iteration
    """

    # number of training examples
    m = X.shape[0]

    # to store loss values for every iteation as a list and print loss value after every 100 iterations
    loss_hist = []

    # Initialize parameters
    w = copy.deepcopy(w_initial) ## deepcopy is used so that the updates do not change the initial variable values
    b = b_initial

    ### START CODE HERE ###
    for i in range(num_iters):
        dL_dw, dL_db = compute_gradient(X, y, w, b)
        w -= alpha * dL_dw
        b -= alpha * dL_db
        loss = loss_function(X, y, w, b)
        loss_hist.append(loss)
        if i % 100 == 0:
            print(f"Iteration {i}: Loss = {loss:.4f}")



    ### END CODE HERE ###

    return w, b, loss_hist

# %% [markdown]
# Now you have to intialize the model parameters ($w$ and $b$) and learning rate (```alpha```). The learning rate ```alpha``` has to be randomly initialized between 0.0001 and 0.001. For the learning rate, you have to first set the last two digits of your roll number as the random seed using ```random.seed()``` function.

# %%
## CODE REQUIRED ##

## set the last two digits of your roll number as the random seed
random_seed = None
### START CODE HERE ###
random_seed = 28
### END CODE HERE ###
np.random.seed(random_seed)

def initialize_parameters():
    """
    This function randomly initializes the model parameters (w and b) and the hyperparameter alpha
    Initial w and b should be randomly sampled from a normal distribution with mean 0
    alpha should be randomly initialized between 0.0001 and 0.001 by using last two digits of your roll number as the random seed
    Args:
        None
    Returns:
        initial_w: Initial parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        initial_b: Initial bias parameter (scalar) of the linear regression model
        alpha: Learning rate
    """

    initial_w = None
    initial_b = None
    alpha = None

    ### START CODE HERE ###
    n_features = X.shape[1]
    initial_w = np.random.randn(1, n_features)
    initial_b = np.random.randn()
    alpha = random.uniform(0.0001, 0.001)




    ### END CODE HERE ###

    return initial_w,initial_b,alpha

# %% [markdown]
# In the next cell, the model is trained using batch gradient descent algorithm for ```num_iters=10000``` iterations. You can change the number of iterations to check any improvements in the performance.

# %%
# initialize the parameters and hyperparameter
initial_w, initial_b, alpha = initialize_parameters()

# number of iterations
num_iters = 100000

w,b,loss_hist = batch_gradient_descent(X_train ,y_train, initial_w, initial_b, alpha, num_iters)
print("Updated w: ",w)
print("Updated b: ",b)
# Out:
# Iteration 0: Loss = 777.7438
# Iteration 100: Loss = 726.0034
# Iteration 200: Loss = 678.1144
# Iteration 300: Loss = 633.7892
# Iteration 400: Loss = 592.7617
# Iteration 500: Loss = 554.7857
# Iteration 600: Loss = 519.6333
# Iteration 700: Loss = 487.0938
# Iteration 800: Loss = 456.9721
# Iteration 900: Loss = 429.0877
# Iteration 1000: Loss = 403.2734
# Iteration 1100: Loss = 379.3749
# Iteration 1200: Loss = 357.2491
# Iteration 1300: Loss = 336.7636
# Iteration 1400: Loss = 317.7959
# Iteration 1500: Loss = 300.2329
# Iteration 1600: Loss = 283.9696
# Iteration 1700: Loss = 268.9090
# Iteration 1800: Loss = 254.9614
# Iteration 1900: Loss = 242.0437
# Iteration 2000: Loss = 230.0790
# Iteration 2100: Loss = 218.9962
# Iteration 2200: Loss = 208.7295
# Iteration 2300: Loss = 199.2179
# Iteration 2400: Loss = 190.4053
# Iteration 2500: Loss = 182.2393
# Iteration 2600: Loss = 174.6717
# Iteration 2700: Loss = 167.6580
# Iteration 2800: Loss = 161.1567
# Iteration 2900: Loss = 155.1297
# Iteration 3000: Loss = 149.5416
# Iteration 3100: Loss = 144.3597
# Iteration 3200: Loss = 139.5536
# Iteration 3300: Loss = 135.0954
# Iteration 3400: Loss = 130.9591
# Iteration 3500: Loss = 127.1207
# Iteration 3600: Loss = 123.5580
# Iteration 3700: Loss = 120.2505
# Iteration 3800: Loss = 117.1791
# Iteration 3900: Loss = 114.3263
# Iteration 4000: Loss = 111.6758
# Iteration 4100: Loss = 109.2125
# Iteration 4200: Loss = 106.9224
# Iteration 4300: Loss = 104.7928
# Iteration 4400: Loss = 102.8116
# Iteration 4500: Loss = 100.9678
# Iteration 4600: Loss = 99.2512
# Iteration 4700: Loss = 97.6523
# Iteration 4800: Loss = 96.1624
# Iteration 4900: Loss = 94.7733
# Iteration 5000: Loss = 93.4777
# Iteration 5100: Loss = 92.2685
# Iteration 5200: Loss = 91.1393
# Iteration 5300: Loss = 90.0843
# Iteration 5400: Loss = 89.0978
# Iteration 5500: Loss = 88.1749
# Iteration 5600: Loss = 87.3108
# Iteration 5700: Loss = 86.5012
# Iteration 5800: Loss = 85.7420
# Iteration 5900: Loss = 85.0295
# Iteration 6000: Loss = 84.3602
# Iteration 6100: Loss = 83.7311
# Iteration 6200: Loss = 83.1390
# Iteration 6300: Loss = 82.5814
# Iteration 6400: Loss = 82.0556
# Iteration 6500: Loss = 81.5593
# Iteration 6600: Loss = 81.0904
# Iteration 6700: Loss = 80.6468
# Iteration 6800: Loss = 80.2267
# Iteration 6900: Loss = 79.8283
# Iteration 7000: Loss = 79.4502
# Iteration 7100: Loss = 79.0907
# Iteration 7200: Loss = 78.7486
# Iteration 7300: Loss = 78.4227
# Iteration 7400: Loss = 78.1116
# Iteration 7500: Loss = 77.8144
# Iteration 7600: Loss = 77.5300
# Iteration 7700: Loss = 77.2576
# Iteration 7800: Loss = 76.9963
# Iteration 7900: Loss = 76.7452
# Iteration 8000: Loss = 76.5037
# Iteration 8100: Loss = 76.2711
# Iteration 8200: Loss = 76.0467
# Iteration 8300: Loss = 75.8299
# Iteration 8400: Loss = 75.6204
# Iteration 8500: Loss = 75.4174
# Iteration 8600: Loss = 75.2206
# Iteration 8700: Loss = 75.0296
# Iteration 8800: Loss = 74.8439
# Iteration 8900: Loss = 74.6632
# Iteration 9000: Loss = 74.4871
# Iteration 9100: Loss = 74.3154
# Iteration 9200: Loss = 74.1477
# Iteration 9300: Loss = 73.9838
# Iteration 9400: Loss = 73.8235
# Iteration 9500: Loss = 73.6664
# Iteration 9600: Loss = 73.5125
# Iteration 9700: Loss = 73.3614
# Iteration 9800: Loss = 73.2130
# Iteration 9900: Loss = 73.0672
# Iteration 10000: Loss = 72.9237
# Iteration 10100: Loss = 72.7825
# Iteration 10200: Loss = 72.6434
# Iteration 10300: Loss = 72.5062
# Iteration 10400: Loss = 72.3709
# Iteration 10500: Loss = 72.2374
# Iteration 10600: Loss = 72.1056
# Iteration 10700: Loss = 71.9753
# Iteration 10800: Loss = 71.8464
# Iteration 10900: Loss = 71.7190
# Iteration 11000: Loss = 71.5929
# Iteration 11100: Loss = 71.4681
# Iteration 11200: Loss = 71.3445
# Iteration 11300: Loss = 71.2220
# Iteration 11400: Loss = 71.1006
# Iteration 11500: Loss = 70.9802
# Iteration 11600: Loss = 70.8608
# Iteration 11700: Loss = 70.7424
# Iteration 11800: Loss = 70.6249
# Iteration 11900: Loss = 70.5082
# Iteration 12000: Loss = 70.3924
# Iteration 12100: Loss = 70.2774
# Iteration 12200: Loss = 70.1631
# Iteration 12300: Loss = 70.0496
# Iteration 12400: Loss = 69.9368
# Iteration 12500: Loss = 69.8247
# Iteration 12600: Loss = 69.7133
# Iteration 12700: Loss = 69.6025
# Iteration 12800: Loss = 69.4924
# Iteration 12900: Loss = 69.3829
# Iteration 13000: Loss = 69.2740
# Iteration 13100: Loss = 69.1656
# Iteration 13200: Loss = 69.0578
# Iteration 13300: Loss = 68.9506
# Iteration 13400: Loss = 68.8439
# Iteration 13500: Loss = 68.7378
# Iteration 13600: Loss = 68.6321
# Iteration 13700: Loss = 68.5270
# Iteration 13800: Loss = 68.4224
# Iteration 13900: Loss = 68.3182
# Iteration 14000: Loss = 68.2146
# Iteration 14100: Loss = 68.1114
# Iteration 14200: Loss = 68.0087
# Iteration 14300: Loss = 67.9064
# Iteration 14400: Loss = 67.8046
# Iteration 14500: Loss = 67.7032
# Iteration 14600: Loss = 67.6022
# Iteration 14700: Loss = 67.5017
# Iteration 14800: Loss = 67.4016
# Iteration 14900: Loss = 67.3020
# Iteration 15000: Loss = 67.2027
# Iteration 15100: Loss = 67.1039
# Iteration 15200: Loss = 67.0055
# Iteration 15300: Loss = 66.9075
# Iteration 15400: Loss = 66.8099
# Iteration 15500: Loss = 66.7126
# Iteration 15600: Loss = 66.6158
# Iteration 15700: Loss = 66.5194
# Iteration 15800: Loss = 66.4233
# Iteration 15900: Loss = 66.3276
# Iteration 16000: Loss = 66.2323
# Iteration 16100: Loss = 66.1374
# Iteration 16200: Loss = 66.0429
# Iteration 16300: Loss = 65.9487
# Iteration 16400: Loss = 65.8549
# Iteration 16500: Loss = 65.7615
# Iteration 16600: Loss = 65.6684
# Iteration 16700: Loss = 65.5757
# Iteration 16800: Loss = 65.4834
# Iteration 16900: Loss = 65.3914
# Iteration 17000: Loss = 65.2997
# Iteration 17100: Loss = 65.2085
# Iteration 17200: Loss = 65.1175
# Iteration 17300: Loss = 65.0269
# Iteration 17400: Loss = 64.9367
# Iteration 17500: Loss = 64.8468
# Iteration 17600: Loss = 64.7573
# Iteration 17700: Loss = 64.6681
# Iteration 17800: Loss = 64.5792
# Iteration 17900: Loss = 64.4907
# Iteration 18000: Loss = 64.4025
# Iteration 18100: Loss = 64.3146
# Iteration 18200: Loss = 64.2271
# Iteration 18300: Loss = 64.1399
# Iteration 18400: Loss = 64.0531
# Iteration 18500: Loss = 63.9665
# Iteration 18600: Loss = 63.8803
# Iteration 18700: Loss = 63.7945
# Iteration 18800: Loss = 63.7089
# Iteration 18900: Loss = 63.6237
# Iteration 19000: Loss = 63.5387
# Iteration 19100: Loss = 63.4542
# Iteration 19200: Loss = 63.3699
# Iteration 19300: Loss = 63.2859
# Iteration 19400: Loss = 63.2023
# Iteration 19500: Loss = 63.1189
# Iteration 19600: Loss = 63.0359
# Iteration 19700: Loss = 62.9532
# Iteration 19800: Loss = 62.8708
# Iteration 19900: Loss = 62.7887
# Iteration 20000: Loss = 62.7069
# Iteration 20100: Loss = 62.6255
# Iteration 20200: Loss = 62.5443
# Iteration 20300: Loss = 62.4634
# Iteration 20400: Loss = 62.3828
# Iteration 20500: Loss = 62.3026
# Iteration 20600: Loss = 62.2226
# Iteration 20700: Loss = 62.1429
# Iteration 20800: Loss = 62.0635
# Iteration 20900: Loss = 61.9845
# Iteration 21000: Loss = 61.9057
# Iteration 21100: Loss = 61.8272
# Iteration 21200: Loss = 61.7490
# Iteration 21300: Loss = 61.6711
# Iteration 21400: Loss = 61.5934
# Iteration 21500: Loss = 61.5161
# Iteration 21600: Loss = 61.4390
# Iteration 21700: Loss = 61.3623
# Iteration 21800: Loss = 61.2858
# Iteration 21900: Loss = 61.2096
# Iteration 22000: Loss = 61.1337
# Iteration 22100: Loss = 61.0580
# Iteration 22200: Loss = 60.9827
# Iteration 22300: Loss = 60.9076
# Iteration 22400: Loss = 60.8328
# Iteration 22500: Loss = 60.7582
# Iteration 22600: Loss = 60.6840
# Iteration 22700: Loss = 60.6100
# Iteration 22800: Loss = 60.5363
# Iteration 22900: Loss = 60.4628
# Iteration 23000: Loss = 60.3897
# Iteration 23100: Loss = 60.3168
# Iteration 23200: Loss = 60.2441
# Iteration 23300: Loss = 60.1718
# Iteration 23400: Loss = 60.0997
# Iteration 23500: Loss = 60.0278
# Iteration 23600: Loss = 59.9563
# Iteration 23700: Loss = 59.8850
# Iteration 23800: Loss = 59.8139
# Iteration 23900: Loss = 59.7431
# Iteration 24000: Loss = 59.6726
# Iteration 24100: Loss = 59.6023
# Iteration 24200: Loss = 59.5323
# Iteration 24300: Loss = 59.4626
# Iteration 24400: Loss = 59.3931
# Iteration 24500: Loss = 59.3238
# Iteration 24600: Loss = 59.2548
# Iteration 24700: Loss = 59.1861
# Iteration 24800: Loss = 59.1176
# Iteration 24900: Loss = 59.0493
# Iteration 25000: Loss = 58.9813
# Iteration 25100: Loss = 58.9136
# Iteration 25200: Loss = 58.8461
# Iteration 25300: Loss = 58.7788
# Iteration 25400: Loss = 58.7118
# Iteration 25500: Loss = 58.6450
# Iteration 25600: Loss = 58.5785
# Iteration 25700: Loss = 58.5122
# Iteration 25800: Loss = 58.4462
# Iteration 25900: Loss = 58.3803
# Iteration 26000: Loss = 58.3148
# Iteration 26100: Loss = 58.2494
# Iteration 26200: Loss = 58.1844
# Iteration 26300: Loss = 58.1195
# Iteration 26400: Loss = 58.0549
# Iteration 26500: Loss = 57.9905
# Iteration 26600: Loss = 57.9263
# Iteration 26700: Loss = 57.8624
# Iteration 26800: Loss = 57.7987
# Iteration 26900: Loss = 57.7352
# Iteration 27000: Loss = 57.6720
# Iteration 27100: Loss = 57.6090
# Iteration 27200: Loss = 57.5462
# Iteration 27300: Loss = 57.4836
# Iteration 27400: Loss = 57.4213
# Iteration 27500: Loss = 57.3592
# Iteration 27600: Loss = 57.2973
# Iteration 27700: Loss = 57.2357
# Iteration 27800: Loss = 57.1742
# Iteration 27900: Loss = 57.1130
# Iteration 28000: Loss = 57.0520
# Iteration 28100: Loss = 56.9912
# Iteration 28200: Loss = 56.9306
# Iteration 28300: Loss = 56.8703
# Iteration 28400: Loss = 56.8102
# Iteration 28500: Loss = 56.7503
# Iteration 28600: Loss = 56.6906
# Iteration 28700: Loss = 56.6311
# Iteration 28800: Loss = 56.5718
# Iteration 28900: Loss = 56.5127
# Iteration 29000: Loss = 56.4539
# Iteration 29100: Loss = 56.3952
# Iteration 29200: Loss = 56.3368
# Iteration 29300: Loss = 56.2786
# Iteration 29400: Loss = 56.2205
# Iteration 29500: Loss = 56.1627
# Iteration 29600: Loss = 56.1051
# Iteration 29700: Loss = 56.0477
# Iteration 29800: Loss = 55.9905
# Iteration 29900: Loss = 55.9335
# Iteration 30000: Loss = 55.8767
# Iteration 30100: Loss = 55.8202
# Iteration 30200: Loss = 55.7638
# Iteration 30300: Loss = 55.7076
# Iteration 30400: Loss = 55.6516
# Iteration 30500: Loss = 55.5958
# Iteration 30600: Loss = 55.5402
# Iteration 30700: Loss = 55.4848
# Iteration 30800: Loss = 55.4296
# Iteration 30900: Loss = 55.3746
# Iteration 31000: Loss = 55.3198
# Iteration 31100: Loss = 55.2652
# Iteration 31200: Loss = 55.2107
# Iteration 31300: Loss = 55.1565
# Iteration 31400: Loss = 55.1024
# Iteration 31500: Loss = 55.0486
# Iteration 31600: Loss = 54.9949
# Iteration 31700: Loss = 54.9414
# Iteration 31800: Loss = 54.8882
# Iteration 31900: Loss = 54.8351
# Iteration 32000: Loss = 54.7821
# Iteration 32100: Loss = 54.7294
# Iteration 32200: Loss = 54.6769
# Iteration 32300: Loss = 54.6245
# Iteration 32400: Loss = 54.5723
# Iteration 32500: Loss = 54.5204
# Iteration 32600: Loss = 54.4685
# Iteration 32700: Loss = 54.4169
# Iteration 32800: Loss = 54.3655
# Iteration 32900: Loss = 54.3142
# Iteration 33000: Loss = 54.2631
# Iteration 33100: Loss = 54.2122
# Iteration 33200: Loss = 54.1615
# Iteration 33300: Loss = 54.1109
# Iteration 33400: Loss = 54.0605
# Iteration 33500: Loss = 54.0103
# Iteration 33600: Loss = 53.9603
# Iteration 33700: Loss = 53.9104
# Iteration 33800: Loss = 53.8608
# Iteration 33900: Loss = 53.8112
# Iteration 34000: Loss = 53.7619
# Iteration 34100: Loss = 53.7127
# Iteration 34200: Loss = 53.6637
# Iteration 34300: Loss = 53.6149
# Iteration 34400: Loss = 53.5663
# Iteration 34500: Loss = 53.5178
# Iteration 34600: Loss = 53.4695
# Iteration 34700: Loss = 53.4213
# Iteration 34800: Loss = 53.3733
# Iteration 34900: Loss = 53.3255
# Iteration 35000: Loss = 53.2778
# Iteration 35100: Loss = 53.2304
# Iteration 35200: Loss = 53.1830
# Iteration 35300: Loss = 53.1359
# Iteration 35400: Loss = 53.0889
# Iteration 35500: Loss = 53.0420
# Iteration 35600: Loss = 52.9953
# Iteration 35700: Loss = 52.9488
# Iteration 35800: Loss = 52.9025
# Iteration 35900: Loss = 52.8563
# Iteration 36000: Loss = 52.8102
# Iteration 36100: Loss = 52.7644
# Iteration 36200: Loss = 52.7186
# Iteration 36300: Loss = 52.6731
# Iteration 36400: Loss = 52.6277
# Iteration 36500: Loss = 52.5824
# Iteration 36600: Loss = 52.5373
# Iteration 36700: Loss = 52.4924
# Iteration 36800: Loss = 52.4476
# Iteration 36900: Loss = 52.4029
# Iteration 37000: Loss = 52.3584
# Iteration 37100: Loss = 52.3141
# Iteration 37200: Loss = 52.2699
# Iteration 37300: Loss = 52.2259
# Iteration 37400: Loss = 52.1820
# Iteration 37500: Loss = 52.1383
# Iteration 37600: Loss = 52.0947
# Iteration 37700: Loss = 52.0513
# Iteration 37800: Loss = 52.0080
# Iteration 37900: Loss = 51.9648
# Iteration 38000: Loss = 51.9218
# Iteration 38100: Loss = 51.8790
# Iteration 38200: Loss = 51.8363
# Iteration 38300: Loss = 51.7937
# Iteration 38400: Loss = 51.7513
# Iteration 38500: Loss = 51.7090
# Iteration 38600: Loss = 51.6669
# Iteration 38700: Loss = 51.6249
# Iteration 38800: Loss = 51.5831
# Iteration 38900: Loss = 51.5414
# Iteration 39000: Loss = 51.4998
# Iteration 39100: Loss = 51.4584
# Iteration 39200: Loss = 51.4171
# Iteration 39300: Loss = 51.3760
# Iteration 39400: Loss = 51.3350
# Iteration 39500: Loss = 51.2941
# Iteration 39600: Loss = 51.2534
# Iteration 39700: Loss = 51.2128
# Iteration 39800: Loss = 51.1723
# Iteration 39900: Loss = 51.1320
# Iteration 40000: Loss = 51.0918
# Iteration 40100: Loss = 51.0518
# Iteration 40200: Loss = 51.0119
# Iteration 40300: Loss = 50.9721
# Iteration 40400: Loss = 50.9325
# Iteration 40500: Loss = 50.8929
# Iteration 40600: Loss = 50.8536
# Iteration 40700: Loss = 50.8143
# Iteration 40800: Loss = 50.7752
# Iteration 40900: Loss = 50.7362
# Iteration 41000: Loss = 50.6973
# Iteration 41100: Loss = 50.6586
# Iteration 41200: Loss = 50.6200
# Iteration 41300: Loss = 50.5815
# Iteration 41400: Loss = 50.5432
# Iteration 41500: Loss = 50.5050
# Iteration 41600: Loss = 50.4669
# Iteration 41700: Loss = 50.4289
# Iteration 41800: Loss = 50.3911
# Iteration 41900: Loss = 50.3534
# Iteration 42000: Loss = 50.3158
# Iteration 42100: Loss = 50.2783
# Iteration 42200: Loss = 50.2410
# Iteration 42300: Loss = 50.2038
# Iteration 42400: Loss = 50.1667
# Iteration 42500: Loss = 50.1297
# Iteration 42600: Loss = 50.0929
# Iteration 42700: Loss = 50.0561
# Iteration 42800: Loss = 50.0195
# Iteration 42900: Loss = 49.9831
# Iteration 43000: Loss = 49.9467
# Iteration 43100: Loss = 49.9105
# Iteration 43200: Loss = 49.8743
# Iteration 43300: Loss = 49.8383
# Iteration 43400: Loss = 49.8024
# Iteration 43500: Loss = 49.7667
# Iteration 43600: Loss = 49.7310
# Iteration 43700: Loss = 49.6955
# Iteration 43800: Loss = 49.6601
# Iteration 43900: Loss = 49.6248
# Iteration 44000: Loss = 49.5896
# Iteration 44100: Loss = 49.5545
# Iteration 44200: Loss = 49.5195
# Iteration 44300: Loss = 49.4847
# Iteration 44400: Loss = 49.4500
# Iteration 44500: Loss = 49.4154
# Iteration 44600: Loss = 49.3809
# Iteration 44700: Loss = 49.3465
# Iteration 44800: Loss = 49.3122
# Iteration 44900: Loss = 49.2780
# Iteration 45000: Loss = 49.2440
# Iteration 45100: Loss = 49.2100
# Iteration 45200: Loss = 49.1762
# Iteration 45300: Loss = 49.1425
# Iteration 45400: Loss = 49.1088
# Iteration 45500: Loss = 49.0753
# Iteration 45600: Loss = 49.0419
# Iteration 45700: Loss = 49.0087
# Iteration 45800: Loss = 48.9755
# Iteration 45900: Loss = 48.9424
# Iteration 46000: Loss = 48.9094
# Iteration 46100: Loss = 48.8766
# Iteration 46200: Loss = 48.8438
# Iteration 46300: Loss = 48.8112
# Iteration 46400: Loss = 48.7786
# Iteration 46500: Loss = 48.7462
# Iteration 46600: Loss = 48.7138
# Iteration 46700: Loss = 48.6816
# Iteration 46800: Loss = 48.6495
# Iteration 46900: Loss = 48.6175
# Iteration 47000: Loss = 48.5855
# Iteration 47100: Loss = 48.5537
# Iteration 47200: Loss = 48.5220
# Iteration 47300: Loss = 48.4904
# Iteration 47400: Loss = 48.4589
# Iteration 47500: Loss = 48.4275
# Iteration 47600: Loss = 48.3962
# Iteration 47700: Loss = 48.3649
# Iteration 47800: Loss = 48.3338
# Iteration 47900: Loss = 48.3028
# Iteration 48000: Loss = 48.2719
# Iteration 48100: Loss = 48.2411
# Iteration 48200: Loss = 48.2104
# Iteration 48300: Loss = 48.1798
# Iteration 48400: Loss = 48.1492
# Iteration 48500: Loss = 48.1188
# Iteration 48600: Loss = 48.0885
# Iteration 48700: Loss = 48.0582
# Iteration 48800: Loss = 48.0281
# Iteration 48900: Loss = 47.9981
# Iteration 49000: Loss = 47.9681
# Iteration 49100: Loss = 47.9383
# Iteration 49200: Loss = 47.9085
# Iteration 49300: Loss = 47.8788
# Iteration 49400: Loss = 47.8493
# Iteration 49500: Loss = 47.8198
# Iteration 49600: Loss = 47.7904
# Iteration 49700: Loss = 47.7611
# Iteration 49800: Loss = 47.7319
# Iteration 49900: Loss = 47.7028
# Iteration 50000: Loss = 47.6738
# Iteration 50100: Loss = 47.6449
# Iteration 50200: Loss = 47.6161
# Iteration 50300: Loss = 47.5873
# Iteration 50400: Loss = 47.5587
# Iteration 50500: Loss = 47.5301
# Iteration 50600: Loss = 47.5016
# Iteration 50700: Loss = 47.4732
# Iteration 50800: Loss = 47.4450
# Iteration 50900: Loss = 47.4167
# Iteration 51000: Loss = 47.3886
# Iteration 51100: Loss = 47.3606
# Iteration 51200: Loss = 47.3327
# Iteration 51300: Loss = 47.3048
# Iteration 51400: Loss = 47.2770
# Iteration 51500: Loss = 47.2494
# Iteration 51600: Loss = 47.2218
# Iteration 51700: Loss = 47.1942
# Iteration 51800: Loss = 47.1668
# Iteration 51900: Loss = 47.1395
# Iteration 52000: Loss = 47.1122
# Iteration 52100: Loss = 47.0851
# Iteration 52200: Loss = 47.0580
# Iteration 52300: Loss = 47.0310
# Iteration 52400: Loss = 47.0041
# Iteration 52500: Loss = 46.9772
# Iteration 52600: Loss = 46.9505
# Iteration 52700: Loss = 46.9238
# Iteration 52800: Loss = 46.8972
# Iteration 52900: Loss = 46.8707
# Iteration 53000: Loss = 46.8443
# Iteration 53100: Loss = 46.8179
# Iteration 53200: Loss = 46.7917
# Iteration 53300: Loss = 46.7655
# Iteration 53400: Loss = 46.7394
# Iteration 53500: Loss = 46.7134
# Iteration 53600: Loss = 46.6874
# Iteration 53700: Loss = 46.6616
# Iteration 53800: Loss = 46.6358
# Iteration 53900: Loss = 46.6101
# Iteration 54000: Loss = 46.5845
# Iteration 54100: Loss = 46.5589
# Iteration 54200: Loss = 46.5335
# Iteration 54300: Loss = 46.5081
# Iteration 54400: Loss = 46.4828
# Iteration 54500: Loss = 46.4575
# Iteration 54600: Loss = 46.4324
# Iteration 54700: Loss = 46.4073
# Iteration 54800: Loss = 46.3823
# Iteration 54900: Loss = 46.3574
# Iteration 55000: Loss = 46.3325
# Iteration 55100: Loss = 46.3077
# Iteration 55200: Loss = 46.2830
# Iteration 55300: Loss = 46.2584
# Iteration 55400: Loss = 46.2338
# Iteration 55500: Loss = 46.2094
# Iteration 55600: Loss = 46.1850
# Iteration 55700: Loss = 46.1606
# Iteration 55800: Loss = 46.1364
# Iteration 55900: Loss = 46.1122
# Iteration 56000: Loss = 46.0881
# Iteration 56100: Loss = 46.0640
# Iteration 56200: Loss = 46.0401
# Iteration 56300: Loss = 46.0162
# Iteration 56400: Loss = 45.9924
# Iteration 56500: Loss = 45.9686
# Iteration 56600: Loss = 45.9449
# Iteration 56700: Loss = 45.9213
# Iteration 56800: Loss = 45.8978
# Iteration 56900: Loss = 45.8743
# Iteration 57000: Loss = 45.8509
# Iteration 57100: Loss = 45.8276
# Iteration 57200: Loss = 45.8043
# Iteration 57300: Loss = 45.7812
# Iteration 57400: Loss = 45.7580
# Iteration 57500: Loss = 45.7350
# Iteration 57600: Loss = 45.7120
# Iteration 57700: Loss = 45.6891
# Iteration 57800: Loss = 45.6663
# Iteration 57900: Loss = 45.6435
# Iteration 58000: Loss = 45.6208
# Iteration 58100: Loss = 45.5981
# Iteration 58200: Loss = 45.5756
# Iteration 58300: Loss = 45.5530
# Iteration 58400: Loss = 45.5306
# Iteration 58500: Loss = 45.5082
# Iteration 58600: Loss = 45.4859
# Iteration 58700: Loss = 45.4637
# Iteration 58800: Loss = 45.4415
# Iteration 58900: Loss = 45.4194
# Iteration 59000: Loss = 45.3974
# Iteration 59100: Loss = 45.3754
# Iteration 59200: Loss = 45.3535
# Iteration 59300: Loss = 45.3316
# Iteration 59400: Loss = 45.3098
# Iteration 59500: Loss = 45.2881
# Iteration 59600: Loss = 45.2664
# Iteration 59700: Loss = 45.2448
# Iteration 59800: Loss = 45.2233
# Iteration 59900: Loss = 45.2018
# Iteration 60000: Loss = 45.1804
# Iteration 60100: Loss = 45.1591
# Iteration 60200: Loss = 45.1378
# Iteration 60300: Loss = 45.1166
# Iteration 60400: Loss = 45.0954
# Iteration 60500: Loss = 45.0743
# Iteration 60600: Loss = 45.0533
# Iteration 60700: Loss = 45.0323
# Iteration 60800: Loss = 45.0114
# Iteration 60900: Loss = 44.9906
# Iteration 61000: Loss = 44.9698
# Iteration 61100: Loss = 44.9491
# Iteration 61200: Loss = 44.9284
# Iteration 61300: Loss = 44.9078
# Iteration 61400: Loss = 44.8872
# Iteration 61500: Loss = 44.8667
# Iteration 61600: Loss = 44.8463
# Iteration 61700: Loss = 44.8259
# Iteration 61800: Loss = 44.8056
# Iteration 61900: Loss = 44.7854
# Iteration 62000: Loss = 44.7652
# Iteration 62100: Loss = 44.7450
# Iteration 62200: Loss = 44.7250
# Iteration 62300: Loss = 44.7049
# Iteration 62400: Loss = 44.6850
# Iteration 62500: Loss = 44.6651
# Iteration 62600: Loss = 44.6452
# Iteration 62700: Loss = 44.6254
# Iteration 62800: Loss = 44.6057
# Iteration 62900: Loss = 44.5860
# Iteration 63000: Loss = 44.5664
# Iteration 63100: Loss = 44.5468
# Iteration 63200: Loss = 44.5273
# Iteration 63300: Loss = 44.5078
# Iteration 63400: Loss = 44.4884
# Iteration 63500: Loss = 44.4691
# Iteration 63600: Loss = 44.4498
# Iteration 63700: Loss = 44.4306
# Iteration 63800: Loss = 44.4114
# Iteration 63900: Loss = 44.3923
# Iteration 64000: Loss = 44.3732
# Iteration 64100: Loss = 44.3542
# Iteration 64200: Loss = 44.3352
# Iteration 64300: Loss = 44.3163
# Iteration 64400: Loss = 44.2974
# Iteration 64500: Loss = 44.2786
# Iteration 64600: Loss = 44.2599
# Iteration 64700: Loss = 44.2412
# Iteration 64800: Loss = 44.2225
# Iteration 64900: Loss = 44.2040
# Iteration 65000: Loss = 44.1854
# Iteration 65100: Loss = 44.1669
# Iteration 65200: Loss = 44.1485
# Iteration 65300: Loss = 44.1301
# Iteration 65400: Loss = 44.1118
# Iteration 65500: Loss = 44.0935
# Iteration 65600: Loss = 44.0753
# Iteration 65700: Loss = 44.0571
# Iteration 65800: Loss = 44.0390
# Iteration 65900: Loss = 44.0209
# Iteration 66000: Loss = 44.0029
# Iteration 66100: Loss = 43.9849
# Iteration 66200: Loss = 43.9670
# Iteration 66300: Loss = 43.9491
# Iteration 66400: Loss = 43.9312
# Iteration 66500: Loss = 43.9135
# Iteration 66600: Loss = 43.8957
# Iteration 66700: Loss = 43.8781
# Iteration 66800: Loss = 43.8604
# Iteration 66900: Loss = 43.8429
# Iteration 67000: Loss = 43.8253
# Iteration 67100: Loss = 43.8078
# Iteration 67200: Loss = 43.7904
# Iteration 67300: Loss = 43.7730
# Iteration 67400: Loss = 43.7557
# Iteration 67500: Loss = 43.7384
# Iteration 67600: Loss = 43.7212
# Iteration 67700: Loss = 43.7040
# Iteration 67800: Loss = 43.6868
# Iteration 67900: Loss = 43.6697
# Iteration 68000: Loss = 43.6527
# Iteration 68100: Loss = 43.6357
# Iteration 68200: Loss = 43.6187
# Iteration 68300: Loss = 43.6018
# Iteration 68400: Loss = 43.5849
# Iteration 68500: Loss = 43.5681
# Iteration 68600: Loss = 43.5513
# Iteration 68700: Loss = 43.5346
# Iteration 68800: Loss = 43.5179
# Iteration 68900: Loss = 43.5013
# Iteration 69000: Loss = 43.4847
# Iteration 69100: Loss = 43.4681
# Iteration 69200: Loss = 43.4516
# Iteration 69300: Loss = 43.4352
# Iteration 69400: Loss = 43.4188
# Iteration 69500: Loss = 43.4024
# Iteration 69600: Loss = 43.3861
# Iteration 69700: Loss = 43.3698
# Iteration 69800: Loss = 43.3535
# Iteration 69900: Loss = 43.3374
# Iteration 70000: Loss = 43.3212
# Iteration 70100: Loss = 43.3051
# Iteration 70200: Loss = 43.2890
# Iteration 70300: Loss = 43.2730
# Iteration 70400: Loss = 43.2571
# Iteration 70500: Loss = 43.2411
# Iteration 70600: Loss = 43.2252
# Iteration 70700: Loss = 43.2094
# Iteration 70800: Loss = 43.1936
# Iteration 70900: Loss = 43.1778
# Iteration 71000: Loss = 43.1621
# Iteration 71100: Loss = 43.1464
# Iteration 71200: Loss = 43.1308
# Iteration 71300: Loss = 43.1152
# Iteration 71400: Loss = 43.0997
# Iteration 71500: Loss = 43.0841
# Iteration 71600: Loss = 43.0687
# Iteration 71700: Loss = 43.0533
# Iteration 71800: Loss = 43.0379
# Iteration 71900: Loss = 43.0225
# Iteration 72000: Loss = 43.0072
# Iteration 72100: Loss = 42.9920
# Iteration 72200: Loss = 42.9767
# Iteration 72300: Loss = 42.9616
# Iteration 72400: Loss = 42.9464
# Iteration 72500: Loss = 42.9313
# Iteration 72600: Loss = 42.9162
# Iteration 72700: Loss = 42.9012
# Iteration 72800: Loss = 42.8862
# Iteration 72900: Loss = 42.8713
# Iteration 73000: Loss = 42.8564
# Iteration 73100: Loss = 42.8415
# Iteration 73200: Loss = 42.8267
# Iteration 73300: Loss = 42.8119
# Iteration 73400: Loss = 42.7972
# Iteration 73500: Loss = 42.7825
# Iteration 73600: Loss = 42.7678
# Iteration 73700: Loss = 42.7532
# Iteration 73800: Loss = 42.7386
# Iteration 73900: Loss = 42.7240
# Iteration 74000: Loss = 42.7095
# Iteration 74100: Loss = 42.6950
# Iteration 74200: Loss = 42.6806
# Iteration 74300: Loss = 42.6662
# Iteration 74400: Loss = 42.6518
# Iteration 74500: Loss = 42.6375
# Iteration 74600: Loss = 42.6232
# Iteration 74700: Loss = 42.6090
# Iteration 74800: Loss = 42.5947
# Iteration 74900: Loss = 42.5806
# Iteration 75000: Loss = 42.5664
# Iteration 75100: Loss = 42.5523
# Iteration 75200: Loss = 42.5382
# Iteration 75300: Loss = 42.5242
# Iteration 75400: Loss = 42.5102
# Iteration 75500: Loss = 42.4963
# Iteration 75600: Loss = 42.4823
# Iteration 75700: Loss = 42.4684
# Iteration 75800: Loss = 42.4546
# Iteration 75900: Loss = 42.4408
# Iteration 76000: Loss = 42.4270
# Iteration 76100: Loss = 42.4132
# Iteration 76200: Loss = 42.3995
# Iteration 76300: Loss = 42.3859
# Iteration 76400: Loss = 42.3722
# Iteration 76500: Loss = 42.3586
# Iteration 76600: Loss = 42.3450
# Iteration 76700: Loss = 42.3315
# Iteration 76800: Loss = 42.3180
# Iteration 76900: Loss = 42.3045
# Iteration 77000: Loss = 42.2911
# Iteration 77100: Loss = 42.2777
# Iteration 77200: Loss = 42.2643
# Iteration 77300: Loss = 42.2510
# Iteration 77400: Loss = 42.2377
# Iteration 77500: Loss = 42.2244
# Iteration 77600: Loss = 42.2112
# Iteration 77700: Loss = 42.1980
# Iteration 77800: Loss = 42.1849
# Iteration 77900: Loss = 42.1717
# Iteration 78000: Loss = 42.1586
# Iteration 78100: Loss = 42.1456
# Iteration 78200: Loss = 42.1325
# Iteration 78300: Loss = 42.1195
# Iteration 78400: Loss = 42.1066
# Iteration 78500: Loss = 42.0936
# Iteration 78600: Loss = 42.0808
# Iteration 78700: Loss = 42.0679
# Iteration 78800: Loss = 42.0550
# Iteration 78900: Loss = 42.0422
# Iteration 79000: Loss = 42.0295
# Iteration 79100: Loss = 42.0167
# Iteration 79200: Loss = 42.0040
# Iteration 79300: Loss = 41.9914
# Iteration 79400: Loss = 41.9787
# Iteration 79500: Loss = 41.9661
# Iteration 79600: Loss = 41.9535
# Iteration 79700: Loss = 41.9410
# Iteration 79800: Loss = 41.9285
# Iteration 79900: Loss = 41.9160
# Iteration 80000: Loss = 41.9035
# Iteration 80100: Loss = 41.8911
# Iteration 80200: Loss = 41.8787
# Iteration 80300: Loss = 41.8663
# Iteration 80400: Loss = 41.8540
# Iteration 80500: Loss = 41.8417
# Iteration 80600: Loss = 41.8294
# Iteration 80700: Loss = 41.8172
# Iteration 80800: Loss = 41.8050
# Iteration 80900: Loss = 41.7928
# Iteration 81000: Loss = 41.7807
# Iteration 81100: Loss = 41.7685
# Iteration 81200: Loss = 41.7564
# Iteration 81300: Loss = 41.7444
# Iteration 81400: Loss = 41.7324
# Iteration 81500: Loss = 41.7203
# Iteration 81600: Loss = 41.7084
# Iteration 81700: Loss = 41.6964
# Iteration 81800: Loss = 41.6845
# Iteration 81900: Loss = 41.6726
# Iteration 82000: Loss = 41.6608
# Iteration 82100: Loss = 41.6490
# Iteration 82200: Loss = 41.6372
# Iteration 82300: Loss = 41.6254
# Iteration 82400: Loss = 41.6136
# Iteration 82500: Loss = 41.6019
# Iteration 82600: Loss = 41.5902
# Iteration 82700: Loss = 41.5786
# Iteration 82800: Loss = 41.5670
# Iteration 82900: Loss = 41.5554
# Iteration 83000: Loss = 41.5438
# Iteration 83100: Loss = 41.5323
# Iteration 83200: Loss = 41.5207
# Iteration 83300: Loss = 41.5093
# Iteration 83400: Loss = 41.4978
# Iteration 83500: Loss = 41.4864
# Iteration 83600: Loss = 41.4750
# Iteration 83700: Loss = 41.4636
# Iteration 83800: Loss = 41.4522
# Iteration 83900: Loss = 41.4409
# Iteration 84000: Loss = 41.4296
# Iteration 84100: Loss = 41.4183
# Iteration 84200: Loss = 41.4071
# Iteration 84300: Loss = 41.3959
# Iteration 84400: Loss = 41.3847
# Iteration 84500: Loss = 41.3735
# Iteration 84600: Loss = 41.3624
# Iteration 84700: Loss = 41.3513
# Iteration 84800: Loss = 41.3402
# Iteration 84900: Loss = 41.3292
# Iteration 85000: Loss = 41.3181
# Iteration 85100: Loss = 41.3071
# Iteration 85200: Loss = 41.2962
# Iteration 85300: Loss = 41.2852
# Iteration 85400: Loss = 41.2743
# Iteration 85500: Loss = 41.2634
# Iteration 85600: Loss = 41.2525
# Iteration 85700: Loss = 41.2417
# Iteration 85800: Loss = 41.2308
# Iteration 85900: Loss = 41.2201
# Iteration 86000: Loss = 41.2093
# Iteration 86100: Loss = 41.1985
# Iteration 86200: Loss = 41.1878
# Iteration 86300: Loss = 41.1771
# Iteration 86400: Loss = 41.1665
# Iteration 86500: Loss = 41.1558
# Iteration 86600: Loss = 41.1452
# Iteration 86700: Loss = 41.1346
# Iteration 86800: Loss = 41.1240
# Iteration 86900: Loss = 41.1135
# Iteration 87000: Loss = 41.1030
# Iteration 87100: Loss = 41.0925
# Iteration 87200: Loss = 41.0820
# Iteration 87300: Loss = 41.0715
# Iteration 87400: Loss = 41.0611
# Iteration 87500: Loss = 41.0507
# Iteration 87600: Loss = 41.0404
# Iteration 87700: Loss = 41.0300
# Iteration 87800: Loss = 41.0197
# Iteration 87900: Loss = 41.0094
# Iteration 88000: Loss = 40.9991
# Iteration 88100: Loss = 40.9888
# Iteration 88200: Loss = 40.9786
# Iteration 88300: Loss = 40.9684
# Iteration 88400: Loss = 40.9582
# Iteration 88500: Loss = 40.9481
# Iteration 88600: Loss = 40.9379
# Iteration 88700: Loss = 40.9278
# Iteration 88800: Loss = 40.9177
# Iteration 88900: Loss = 40.9077
# Iteration 89000: Loss = 40.8976
# Iteration 89100: Loss = 40.8876
# Iteration 89200: Loss = 40.8776
# Iteration 89300: Loss = 40.8676
# Iteration 89400: Loss = 40.8577
# Iteration 89500: Loss = 40.8477
# Iteration 89600: Loss = 40.8378
# Iteration 89700: Loss = 40.8279
# Iteration 89800: Loss = 40.8181
# Iteration 89900: Loss = 40.8082
# Iteration 90000: Loss = 40.7984
# Iteration 90100: Loss = 40.7886
# Iteration 90200: Loss = 40.7789
# Iteration 90300: Loss = 40.7691
# Iteration 90400: Loss = 40.7594
# Iteration 90500: Loss = 40.7497
# Iteration 90600: Loss = 40.7400
# Iteration 90700: Loss = 40.7303
# Iteration 90800: Loss = 40.7207
# Iteration 90900: Loss = 40.7111
# Iteration 91000: Loss = 40.7015
# Iteration 91100: Loss = 40.6919
# Iteration 91200: Loss = 40.6823
# Iteration 91300: Loss = 40.6728
# Iteration 91400: Loss = 40.6633
# Iteration 91500: Loss = 40.6538
# Iteration 91600: Loss = 40.6443
# Iteration 91700: Loss = 40.6349
# Iteration 91800: Loss = 40.6255
# Iteration 91900: Loss = 40.6161
# Iteration 92000: Loss = 40.6067
# Iteration 92100: Loss = 40.5973
# Iteration 92200: Loss = 40.5880
# Iteration 92300: Loss = 40.5787
# Iteration 92400: Loss = 40.5694
# Iteration 92500: Loss = 40.5601
# Iteration 92600: Loss = 40.5508
# Iteration 92700: Loss = 40.5416
# Iteration 92800: Loss = 40.5324
# Iteration 92900: Loss = 40.5232
# Iteration 93000: Loss = 40.5140
# Iteration 93100: Loss = 40.5048
# Iteration 93200: Loss = 40.4957
# Iteration 93300: Loss = 40.4866
# Iteration 93400: Loss = 40.4775
# Iteration 93500: Loss = 40.4684
# Iteration 93600: Loss = 40.4593
# Iteration 93700: Loss = 40.4503
# Iteration 93800: Loss = 40.4413
# Iteration 93900: Loss = 40.4323
# Iteration 94000: Loss = 40.4233
# Iteration 94100: Loss = 40.4144
# Iteration 94200: Loss = 40.4054
# Iteration 94300: Loss = 40.3965
# Iteration 94400: Loss = 40.3876
# Iteration 94500: Loss = 40.3787
# Iteration 94600: Loss = 40.3699
# Iteration 94700: Loss = 40.3610
# Iteration 94800: Loss = 40.3522
# Iteration 94900: Loss = 40.3434
# Iteration 95000: Loss = 40.3346
# Iteration 95100: Loss = 40.3259
# Iteration 95200: Loss = 40.3171
# Iteration 95300: Loss = 40.3084
# Iteration 95400: Loss = 40.2997
# Iteration 95500: Loss = 40.2910
# Iteration 95600: Loss = 40.2823
# Iteration 95700: Loss = 40.2737
# Iteration 95800: Loss = 40.2650
# Iteration 95900: Loss = 40.2564
# Iteration 96000: Loss = 40.2478
# Iteration 96100: Loss = 40.2393
# Iteration 96200: Loss = 40.2307
# Iteration 96300: Loss = 40.2222
# Iteration 96400: Loss = 40.2136
# Iteration 96500: Loss = 40.2051
# Iteration 96600: Loss = 40.1966
# Iteration 96700: Loss = 40.1882
# Iteration 96800: Loss = 40.1797
# Iteration 96900: Loss = 40.1713
# Iteration 97000: Loss = 40.1629
# Iteration 97100: Loss = 40.1545
# Iteration 97200: Loss = 40.1461
# Iteration 97300: Loss = 40.1378
# Iteration 97400: Loss = 40.1294
# Iteration 97500: Loss = 40.1211
# Iteration 97600: Loss = 40.1128
# Iteration 97700: Loss = 40.1045
# Iteration 97800: Loss = 40.0962
# Iteration 97900: Loss = 40.0880
# Iteration 98000: Loss = 40.0797
# Iteration 98100: Loss = 40.0715
# Iteration 98200: Loss = 40.0633
# Iteration 98300: Loss = 40.0551
# Iteration 98400: Loss = 40.0470
# Iteration 98500: Loss = 40.0388
# Iteration 98600: Loss = 40.0307
# Iteration 98700: Loss = 40.0226
# Iteration 98800: Loss = 40.0145
# Iteration 98900: Loss = 40.0064
# Iteration 99000: Loss = 39.9983
# Iteration 99100: Loss = 39.9903
# Iteration 99200: Loss = 39.9823
# Iteration 99300: Loss = 39.9742
# Iteration 99400: Loss = 39.9662
# Iteration 99500: Loss = 39.9583
# Iteration 99600: Loss = 39.9503
# Iteration 99700: Loss = 39.9424
# Iteration 99800: Loss = 39.9344
# Iteration 99900: Loss = 39.9265
# Updated w:  [[  6.08320735  -5.0009616  -15.65027492  20.94948198]]
# Updated b:  30.472957128870725

# %% [markdown]
# ### 1.5. Final Train Error and Test Error

# %% [markdown]
# After the linear regression model is trained, we will compute the final train error and test error for the trained model.

# %%
## Train and Test error computation

train_error = loss_function(X_train,y_train,w,b)
test_error = loss_function(X_test,y_test,w,b)
print("Train Error: ",train_error, ", Test Error: ",test_error)
# Out:
# Train Error:  39.91869260302093 , Test Error:  70.85706694889306

# %% [markdown]
# ### 1.6. Plotting the loss function

# %% [markdown]
# We will plot the loss function values for every training iteration. If the model is trained properly, you will see that the loss function reduces as the training progesses and it converges at some point.

# %%
# PLotting the loss values for every training iterations

loss_plot = (loss_hist)
plt.xlabel("Iterations")
plt.ylabel("Loss function")
plt.plot(loss_plot)
plt.show()

# %% [markdown]
# ### 1.7 Experimenting with different values of the Hyperparemeters
#
# Previously, we randomly sampled the learning rate and the number of features to train the model. Now, you have to manually choose the number of features and the learning rate. Then, you have to train the model again on the manually choosen hyperparameters (number of features and learning rate). In the next cell, you have to manually choose the hyperparameters and write the code to train the model.
#
# After the model is trained, you have to compare the performance of the model with random chosen hyperparameters and manually chosen hyperparameters.

# %%
## CODE REQUIRED ##

"""
Manually choose the hyperparameters (learning rate and number of features) and train the model.
Then compare the performance with random chosen hyperparameters and manually chosen hyperparameters.
"""

### START CODE HERE ###
X,y=load_data(filepath)
print("Shape of X:",X.shape,"Shape of y:",y.shape)
X=X[:,:6]
print("Shape of X after selecting 6 features:",X.shape,"Shape of y after selecting 6 features:",y.shape)
X = min_max_scaler(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print("Shape of X_train: ",X_train.shape, "Shape of y_train: ",y_train.shape)
print("Shape of X_test: ",X_test.shape, "Shape of y_test: ",y_test.shape)
n_features = X.shape[1]
initial_w = np.random.randn(1, n_features)
initial_b = np.random.randn()
alpha = 0.0004

# number of iterations
num_iters = 100000

w,b,loss_hist = batch_gradient_descent(X_train ,y_train, initial_w, initial_b, alpha, num_iters)
print("Updated w: ",w)
print("Updated b: ",b)

## Train and Test error computation

train_error = loss_function(X_train,y_train,w,b)
test_error = loss_function(X_test,y_test,w,b)
print("Train Error: ",train_error, ", Test Error: ",test_error)

# PLotting the loss values for every training iterations

loss_plot = (loss_hist)
plt.xlabel("Iterations")
plt.ylabel("Loss function")
plt.plot(loss_plot)
plt.show()



### END CODE HERE ###
# Out:
# Shape of X: (414, 6) Shape of y: (414,)
# Shape of X after selecting 6 features: (414, 6) Shape of y after selecting 6 features: (414,)
# Shape of X_train:  (310, 6) Shape of y_train:  (310,)
# Shape of X_test:  (104, 6) Shape of y_test:  (104,)
# Iteration 0: Loss = 817.2406
# Iteration 100: Loss = 691.4585
# Iteration 200: Loss = 586.5449
# Iteration 300: Loss = 499.0324
# Iteration 400: Loss = 426.0299
# Iteration 500: Loss = 365.1268
# Iteration 600: Loss = 314.3127
# Iteration 700: Loss = 271.9117
# Iteration 800: Loss = 236.5259
# Iteration 900: Loss = 206.9900
# Iteration 1000: Loss = 182.3322
# Iteration 1100: Loss = 161.7422
# Iteration 1200: Loss = 144.5442
# Iteration 1300: Loss = 130.1750
# Iteration 1400: Loss = 118.1647
# Iteration 1500: Loss = 108.1215
# Iteration 1600: Loss = 99.7189
# Iteration 1700: Loss = 92.6844
# Iteration 1800: Loss = 86.7909
# Iteration 1900: Loss = 81.8491
# Iteration 2000: Loss = 77.7010
# Iteration 2100: Loss = 74.2150
# Iteration 2200: Loss = 71.2813
# Iteration 2300: Loss = 68.8082
# Iteration 2400: Loss = 66.7195
# Iteration 2500: Loss = 64.9515
# Iteration 2600: Loss = 63.4512
# Iteration 2700: Loss = 62.1741
# Iteration 2800: Loss = 61.0835
# Iteration 2900: Loss = 60.1486
# Iteration 3000: Loss = 59.3436
# Iteration 3100: Loss = 58.6472
# Iteration 3200: Loss = 58.0415
# Iteration 3300: Loss = 57.5117
# Iteration 3400: Loss = 57.0453
# Iteration 3500: Loss = 56.6320
# Iteration 3600: Loss = 56.2631
# Iteration 3700: Loss = 55.9315
# Iteration 3800: Loss = 55.6311
# Iteration 3900: Loss = 55.3569
# Iteration 4000: Loss = 55.1048
# Iteration 4100: Loss = 54.8712
# Iteration 4200: Loss = 54.6533
# Iteration 4300: Loss = 54.4486
# Iteration 4400: Loss = 54.2551
# Iteration 4500: Loss = 54.0712
# Iteration 4600: Loss = 53.8953
# Iteration 4700: Loss = 53.7264
# Iteration 4800: Loss = 53.5634
# Iteration 4900: Loss = 53.4056
# Iteration 5000: Loss = 53.2522
# Iteration 5100: Loss = 53.1026
# Iteration 5200: Loss = 52.9565
# Iteration 5300: Loss = 52.8133
# Iteration 5400: Loss = 52.6728
# Iteration 5500: Loss = 52.5346
# Iteration 5600: Loss = 52.3986
# Iteration 5700: Loss = 52.2645
# Iteration 5800: Loss = 52.1322
# Iteration 5900: Loss = 52.0015
# Iteration 6000: Loss = 51.8723
# Iteration 6100: Loss = 51.7445
# Iteration 6200: Loss = 51.6181
# Iteration 6300: Loss = 51.4929
# Iteration 6400: Loss = 51.3689
# Iteration 6500: Loss = 51.2460
# Iteration 6600: Loss = 51.1243
# Iteration 6700: Loss = 51.0036
# Iteration 6800: Loss = 50.8839
# Iteration 6900: Loss = 50.7652
# Iteration 7000: Loss = 50.6475
# Iteration 7100: Loss = 50.5308
# Iteration 7200: Loss = 50.4150
# Iteration 7300: Loss = 50.3001
# Iteration 7400: Loss = 50.1861
# Iteration 7500: Loss = 50.0730
# Iteration 7600: Loss = 49.9608
# Iteration 7700: Loss = 49.8494
# Iteration 7800: Loss = 49.7389
# Iteration 7900: Loss = 49.6292
# Iteration 8000: Loss = 49.5203
# Iteration 8100: Loss = 49.4123
# Iteration 8200: Loss = 49.3051
# Iteration 8300: Loss = 49.1987
# Iteration 8400: Loss = 49.0930
# Iteration 8500: Loss = 48.9882
# Iteration 8600: Loss = 48.8842
# Iteration 8700: Loss = 48.7809
# Iteration 8800: Loss = 48.6784
# Iteration 8900: Loss = 48.5767
# Iteration 9000: Loss = 48.4757
# Iteration 9100: Loss = 48.3755
# Iteration 9200: Loss = 48.2760
# Iteration 9300: Loss = 48.1772
# Iteration 9400: Loss = 48.0792
# Iteration 9500: Loss = 47.9819
# Iteration 9600: Loss = 47.8853
# Iteration 9700: Loss = 47.7895
# Iteration 9800: Loss = 47.6943
# Iteration 9900: Loss = 47.5999
# Iteration 10000: Loss = 47.5061
# Iteration 10100: Loss = 47.4130
# Iteration 10200: Loss = 47.3207
# Iteration 10300: Loss = 47.2290
# Iteration 10400: Loss = 47.1379
# Iteration 10500: Loss = 47.0476
# Iteration 10600: Loss = 46.9579
# Iteration 10700: Loss = 46.8688
# Iteration 10800: Loss = 46.7804
# Iteration 10900: Loss = 46.6927
# Iteration 11000: Loss = 46.6056
# Iteration 11100: Loss = 46.5192
# Iteration 11200: Loss = 46.4333
# Iteration 11300: Loss = 46.3481
# Iteration 11400: Loss = 46.2636
# Iteration 11500: Loss = 46.1796
# Iteration 11600: Loss = 46.0963
# Iteration 11700: Loss = 46.0135
# Iteration 11800: Loss = 45.9314
# Iteration 11900: Loss = 45.8499
# Iteration 12000: Loss = 45.7689
# Iteration 12100: Loss = 45.6886
# Iteration 12200: Loss = 45.6088
# Iteration 12300: Loss = 45.5296
# Iteration 12400: Loss = 45.4510
# Iteration 12500: Loss = 45.3730
# Iteration 12600: Loss = 45.2955
# Iteration 12700: Loss = 45.2186
# Iteration 12800: Loss = 45.1422
# Iteration 12900: Loss = 45.0664
# Iteration 13000: Loss = 44.9912
# Iteration 13100: Loss = 44.9165
# Iteration 13200: Loss = 44.8423
# Iteration 13300: Loss = 44.7687
# Iteration 13400: Loss = 44.6956
# Iteration 13500: Loss = 44.6230
# Iteration 13600: Loss = 44.5510
# Iteration 13700: Loss = 44.4794
# Iteration 13800: Loss = 44.4084
# Iteration 13900: Loss = 44.3379
# Iteration 14000: Loss = 44.2679
# Iteration 14100: Loss = 44.1984
# Iteration 14200: Loss = 44.1295
# Iteration 14300: Loss = 44.0610
# Iteration 14400: Loss = 43.9930
# Iteration 14500: Loss = 43.9254
# Iteration 14600: Loss = 43.8584
# Iteration 14700: Loss = 43.7919
# Iteration 14800: Loss = 43.7258
# Iteration 14900: Loss = 43.6602
# Iteration 15000: Loss = 43.5950
# Iteration 15100: Loss = 43.5304
# Iteration 15200: Loss = 43.4662
# Iteration 15300: Loss = 43.4024
# Iteration 15400: Loss = 43.3391
# Iteration 15500: Loss = 43.2763
# Iteration 15600: Loss = 43.2139
# Iteration 15700: Loss = 43.1520
# Iteration 15800: Loss = 43.0904
# Iteration 15900: Loss = 43.0294
# Iteration 16000: Loss = 42.9687
# Iteration 16100: Loss = 42.9085
# Iteration 16200: Loss = 42.8488
# Iteration 16300: Loss = 42.7894
# Iteration 16400: Loss = 42.7305
# Iteration 16500: Loss = 42.6720
# Iteration 16600: Loss = 42.6139
# Iteration 16700: Loss = 42.5562
# Iteration 16800: Loss = 42.4989
# Iteration 16900: Loss = 42.4420
# Iteration 17000: Loss = 42.3855
# Iteration 17100: Loss = 42.3295
# Iteration 17200: Loss = 42.2738
# Iteration 17300: Loss = 42.2185
# Iteration 17400: Loss = 42.1636
# Iteration 17500: Loss = 42.1091
# Iteration 17600: Loss = 42.0549
# Iteration 17700: Loss = 42.0012
# Iteration 17800: Loss = 41.9478
# Iteration 17900: Loss = 41.8948
# Iteration 18000: Loss = 41.8422
# Iteration 18100: Loss = 41.7900
# Iteration 18200: Loss = 41.7381
# Iteration 18300: Loss = 41.6865
# Iteration 18400: Loss = 41.6354
# Iteration 18500: Loss = 41.5846
# Iteration 18600: Loss = 41.5341
# Iteration 18700: Loss = 41.4840
# Iteration 18800: Loss = 41.4343
# Iteration 18900: Loss = 41.3849
# Iteration 19000: Loss = 41.3358
# Iteration 19100: Loss = 41.2871
# Iteration 19200: Loss = 41.2387
# Iteration 19300: Loss = 41.1907
# Iteration 19400: Loss = 41.1430
# Iteration 19500: Loss = 41.0956
# Iteration 19600: Loss = 41.0485
# Iteration 19700: Loss = 41.0018
# Iteration 19800: Loss = 40.9554
# Iteration 19900: Loss = 40.9093
# Iteration 20000: Loss = 40.8636
# Iteration 20100: Loss = 40.8181
# Iteration 20200: Loss = 40.7730
# Iteration 20300: Loss = 40.7282
# Iteration 20400: Loss = 40.6837
# Iteration 20500: Loss = 40.6395
# Iteration 20600: Loss = 40.5956
# Iteration 20700: Loss = 40.5520
# Iteration 20800: Loss = 40.5087
# Iteration 20900: Loss = 40.4657
# Iteration 21000: Loss = 40.4230
# Iteration 21100: Loss = 40.3806
# Iteration 21200: Loss = 40.3385
# Iteration 21300: Loss = 40.2967
# Iteration 21400: Loss = 40.2551
# Iteration 21500: Loss = 40.2139
# Iteration 21600: Loss = 40.1729
# Iteration 21700: Loss = 40.1322
# Iteration 21800: Loss = 40.0918
# Iteration 21900: Loss = 40.0517
# Iteration 22000: Loss = 40.0118
# Iteration 22100: Loss = 39.9722
# Iteration 22200: Loss = 39.9329
# Iteration 22300: Loss = 39.8938
# Iteration 22400: Loss = 39.8551
# Iteration 22500: Loss = 39.8165
# Iteration 22600: Loss = 39.7783
# Iteration 22700: Loss = 39.7403
# Iteration 22800: Loss = 39.7025
# Iteration 22900: Loss = 39.6650
# Iteration 23000: Loss = 39.6278
# Iteration 23100: Loss = 39.5908
# Iteration 23200: Loss = 39.5541
# Iteration 23300: Loss = 39.5176
# Iteration 23400: Loss = 39.4814
# Iteration 23500: Loss = 39.4454
# Iteration 23600: Loss = 39.4096
# Iteration 23700: Loss = 39.3741
# Iteration 23800: Loss = 39.3389
# Iteration 23900: Loss = 39.3038
# Iteration 24000: Loss = 39.2690
# Iteration 24100: Loss = 39.2345
# Iteration 24200: Loss = 39.2001
# Iteration 24300: Loss = 39.1660
# Iteration 24400: Loss = 39.1322
# Iteration 24500: Loss = 39.0985
# Iteration 24600: Loss = 39.0651
# Iteration 24700: Loss = 39.0319
# Iteration 24800: Loss = 38.9989
# Iteration 24900: Loss = 38.9662
# Iteration 25000: Loss = 38.9336
# Iteration 25100: Loss = 38.9013
# Iteration 25200: Loss = 38.8692
# Iteration 25300: Loss = 38.8373
# Iteration 25400: Loss = 38.8056
# Iteration 25500: Loss = 38.7742
# Iteration 25600: Loss = 38.7429
# Iteration 25700: Loss = 38.7119
# Iteration 25800: Loss = 38.6810
# Iteration 25900: Loss = 38.6504
# Iteration 26000: Loss = 38.6200
# Iteration 26100: Loss = 38.5897
# Iteration 26200: Loss = 38.5597
# Iteration 26300: Loss = 38.5299
# Iteration 26400: Loss = 38.5002
# Iteration 26500: Loss = 38.4708
# Iteration 26600: Loss = 38.4415
# Iteration 26700: Loss = 38.4125
# Iteration 26800: Loss = 38.3836
# Iteration 26900: Loss = 38.3549
# Iteration 27000: Loss = 38.3264
# Iteration 27100: Loss = 38.2981
# Iteration 27200: Loss = 38.2700
# Iteration 27300: Loss = 38.2421
# Iteration 27400: Loss = 38.2143
# Iteration 27500: Loss = 38.1868
# Iteration 27600: Loss = 38.1594
# Iteration 27700: Loss = 38.1322
# Iteration 27800: Loss = 38.1052
# Iteration 27900: Loss = 38.0783
# Iteration 28000: Loss = 38.0516
# Iteration 28100: Loss = 38.0251
# Iteration 28200: Loss = 37.9988
# Iteration 28300: Loss = 37.9726
# Iteration 28400: Loss = 37.9466
# Iteration 28500: Loss = 37.9208
# Iteration 28600: Loss = 37.8952
# Iteration 28700: Loss = 37.8697
# Iteration 28800: Loss = 37.8444
# Iteration 28900: Loss = 37.8192
# Iteration 29000: Loss = 37.7942
# Iteration 29100: Loss = 37.7694
# Iteration 29200: Loss = 37.7447
# Iteration 29300: Loss = 37.7202
# Iteration 29400: Loss = 37.6958
# Iteration 29500: Loss = 37.6716
# Iteration 29600: Loss = 37.6476
# Iteration 29700: Loss = 37.6237
# Iteration 29800: Loss = 37.6000
# Iteration 29900: Loss = 37.5764
# Iteration 30000: Loss = 37.5529
# Iteration 30100: Loss = 37.5297
# Iteration 30200: Loss = 37.5065
# Iteration 30300: Loss = 37.4835
# Iteration 30400: Loss = 37.4607
# Iteration 30500: Loss = 37.4380
# Iteration 30600: Loss = 37.4155
# Iteration 30700: Loss = 37.3931
# Iteration 30800: Loss = 37.3708
# Iteration 30900: Loss = 37.3487
# Iteration 31000: Loss = 37.3267
# Iteration 31100: Loss = 37.3049
# Iteration 31200: Loss = 37.2832
# Iteration 31300: Loss = 37.2616
# Iteration 31400: Loss = 37.2402
# Iteration 31500: Loss = 37.2189
# Iteration 31600: Loss = 37.1977
# Iteration 31700: Loss = 37.1767
# Iteration 31800: Loss = 37.1558
# Iteration 31900: Loss = 37.1351
# Iteration 32000: Loss = 37.1144
# Iteration 32100: Loss = 37.0939
# Iteration 32200: Loss = 37.0736
# Iteration 32300: Loss = 37.0533
# Iteration 32400: Loss = 37.0332
# Iteration 32500: Loss = 37.0132
# Iteration 32600: Loss = 36.9934
# Iteration 32700: Loss = 36.9736
# Iteration 32800: Loss = 36.9540
# Iteration 32900: Loss = 36.9345
# Iteration 33000: Loss = 36.9152
# Iteration 33100: Loss = 36.8959
# Iteration 33200: Loss = 36.8768
# Iteration 33300: Loss = 36.8578
# Iteration 33400: Loss = 36.8389
# Iteration 33500: Loss = 36.8201
# Iteration 33600: Loss = 36.8015
# Iteration 33700: Loss = 36.7829
# Iteration 33800: Loss = 36.7645
# Iteration 33900: Loss = 36.7462
# Iteration 34000: Loss = 36.7280
# Iteration 34100: Loss = 36.7099
# Iteration 34200: Loss = 36.6919
# Iteration 34300: Loss = 36.6741
# Iteration 34400: Loss = 36.6563
# Iteration 34500: Loss = 36.6387
# Iteration 34600: Loss = 36.6211
# Iteration 34700: Loss = 36.6037
# Iteration 34800: Loss = 36.5864
# Iteration 34900: Loss = 36.5692
# Iteration 35000: Loss = 36.5521
# Iteration 35100: Loss = 36.5351
# Iteration 35200: Loss = 36.5182
# Iteration 35300: Loss = 36.5014
# Iteration 35400: Loss = 36.4847
# Iteration 35500: Loss = 36.4681
# Iteration 35600: Loss = 36.4516
# Iteration 35700: Loss = 36.4352
# Iteration 35800: Loss = 36.4189
# Iteration 35900: Loss = 36.4027
# Iteration 36000: Loss = 36.3867
# Iteration 36100: Loss = 36.3707
# Iteration 36200: Loss = 36.3548
# Iteration 36300: Loss = 36.3390
# Iteration 36400: Loss = 36.3233
# Iteration 36500: Loss = 36.3077
# Iteration 36600: Loss = 36.2921
# Iteration 36700: Loss = 36.2767
# Iteration 36800: Loss = 36.2614
# Iteration 36900: Loss = 36.2462
# Iteration 37000: Loss = 36.2310
# Iteration 37100: Loss = 36.2160
# Iteration 37200: Loss = 36.2010
# Iteration 37300: Loss = 36.1861
# Iteration 37400: Loss = 36.1714
# Iteration 37500: Loss = 36.1567
# Iteration 37600: Loss = 36.1421
# Iteration 37700: Loss = 36.1275
# Iteration 37800: Loss = 36.1131
# Iteration 37900: Loss = 36.0988
# Iteration 38000: Loss = 36.0845
# Iteration 38100: Loss = 36.0703
# Iteration 38200: Loss = 36.0562
# Iteration 38300: Loss = 36.0422
# Iteration 38400: Loss = 36.0283
# Iteration 38500: Loss = 36.0145
# Iteration 38600: Loss = 36.0007
# Iteration 38700: Loss = 35.9870
# Iteration 38800: Loss = 35.9734
# Iteration 38900: Loss = 35.9599
# Iteration 39000: Loss = 35.9465
# Iteration 39100: Loss = 35.9331
# Iteration 39200: Loss = 35.9199
# Iteration 39300: Loss = 35.9067
# Iteration 39400: Loss = 35.8935
# Iteration 39500: Loss = 35.8805
# Iteration 39600: Loss = 35.8675
# Iteration 39700: Loss = 35.8546
# Iteration 39800: Loss = 35.8418
# Iteration 39900: Loss = 35.8291
# Iteration 40000: Loss = 35.8164
# Iteration 40100: Loss = 35.8038
# Iteration 40200: Loss = 35.7913
# Iteration 40300: Loss = 35.7789
# Iteration 40400: Loss = 35.7665
# Iteration 40500: Loss = 35.7542
# Iteration 40600: Loss = 35.7419
# Iteration 40700: Loss = 35.7298
# Iteration 40800: Loss = 35.7177
# Iteration 40900: Loss = 35.7057
# Iteration 41000: Loss = 35.6937
# Iteration 41100: Loss = 35.6819
# Iteration 41200: Loss = 35.6700
# Iteration 41300: Loss = 35.6583
# Iteration 41400: Loss = 35.6466
# Iteration 41500: Loss = 35.6350
# Iteration 41600: Loss = 35.6235
# Iteration 41700: Loss = 35.6120
# Iteration 41800: Loss = 35.6006
# Iteration 41900: Loss = 35.5893
# Iteration 42000: Loss = 35.5780
# Iteration 42100: Loss = 35.5668
# Iteration 42200: Loss = 35.5556
# Iteration 42300: Loss = 35.5445
# Iteration 42400: Loss = 35.5335
# Iteration 42500: Loss = 35.5226
# Iteration 42600: Loss = 35.5117
# Iteration 42700: Loss = 35.5008
# Iteration 42800: Loss = 35.4901
# Iteration 42900: Loss = 35.4793
# Iteration 43000: Loss = 35.4687
# Iteration 43100: Loss = 35.4581
# Iteration 43200: Loss = 35.4476
# Iteration 43300: Loss = 35.4371
# Iteration 43400: Loss = 35.4267
# Iteration 43500: Loss = 35.4163
# Iteration 43600: Loss = 35.4060
# Iteration 43700: Loss = 35.3958
# Iteration 43800: Loss = 35.3856
# Iteration 43900: Loss = 35.3755
# Iteration 44000: Loss = 35.3654
# Iteration 44100: Loss = 35.3554
# Iteration 44200: Loss = 35.3455
# Iteration 44300: Loss = 35.3356
# Iteration 44400: Loss = 35.3257
# Iteration 44500: Loss = 35.3160
# Iteration 44600: Loss = 35.3062
# Iteration 44700: Loss = 35.2965
# Iteration 44800: Loss = 35.2869
# Iteration 44900: Loss = 35.2774
# Iteration 45000: Loss = 35.2678
# Iteration 45100: Loss = 35.2584
# Iteration 45200: Loss = 35.2490
# Iteration 45300: Loss = 35.2396
# Iteration 45400: Loss = 35.2303
# Iteration 45500: Loss = 35.2210
# Iteration 45600: Loss = 35.2118
# Iteration 45700: Loss = 35.2027
# Iteration 45800: Loss = 35.1936
# Iteration 45900: Loss = 35.1845
# Iteration 46000: Loss = 35.1755
# Iteration 46100: Loss = 35.1666
# Iteration 46200: Loss = 35.1577
# Iteration 46300: Loss = 35.1488
# Iteration 46400: Loss = 35.1400
# Iteration 46500: Loss = 35.1312
# Iteration 46600: Loss = 35.1225
# Iteration 46700: Loss = 35.1139
# Iteration 46800: Loss = 35.1052
# Iteration 46900: Loss = 35.0967
# Iteration 47000: Loss = 35.0881
# Iteration 47100: Loss = 35.0797
# Iteration 47200: Loss = 35.0712
# Iteration 47300: Loss = 35.0628
# Iteration 47400: Loss = 35.0545
# Iteration 47500: Loss = 35.0462
# Iteration 47600: Loss = 35.0380
# Iteration 47700: Loss = 35.0298
# Iteration 47800: Loss = 35.0216
# Iteration 47900: Loss = 35.0135
# Iteration 48000: Loss = 35.0054
# Iteration 48100: Loss = 34.9974
# Iteration 48200: Loss = 34.9894
# Iteration 48300: Loss = 34.9814
# Iteration 48400: Loss = 34.9735
# Iteration 48500: Loss = 34.9657
# Iteration 48600: Loss = 34.9579
# Iteration 48700: Loss = 34.9501
# Iteration 48800: Loss = 34.9423
# Iteration 48900: Loss = 34.9346
# Iteration 49000: Loss = 34.9270
# Iteration 49100: Loss = 34.9194
# Iteration 49200: Loss = 34.9118
# Iteration 49300: Loss = 34.9043
# Iteration 49400: Loss = 34.8968
# Iteration 49500: Loss = 34.8893
# Iteration 49600: Loss = 34.8819
# Iteration 49700: Loss = 34.8745
# Iteration 49800: Loss = 34.8672
# Iteration 49900: Loss = 34.8599
# Iteration 50000: Loss = 34.8527
# Iteration 50100: Loss = 34.8454
# Iteration 50200: Loss = 34.8383
# Iteration 50300: Loss = 34.8311
# Iteration 50400: Loss = 34.8240
# Iteration 50500: Loss = 34.8169
# Iteration 50600: Loss = 34.8099
# Iteration 50700: Loss = 34.8029
# Iteration 50800: Loss = 34.7959
# Iteration 50900: Loss = 34.7890
# Iteration 51000: Loss = 34.7821
# Iteration 51100: Loss = 34.7753
# Iteration 51200: Loss = 34.7685
# Iteration 51300: Loss = 34.7617
# Iteration 51400: Loss = 34.7549
# Iteration 51500: Loss = 34.7482
# Iteration 51600: Loss = 34.7415
# Iteration 51700: Loss = 34.7349
# Iteration 51800: Loss = 34.7283
# Iteration 51900: Loss = 34.7217
# Iteration 52000: Loss = 34.7152
# Iteration 52100: Loss = 34.7087
# Iteration 52200: Loss = 34.7022
# Iteration 52300: Loss = 34.6957
# Iteration 52400: Loss = 34.6893
# Iteration 52500: Loss = 34.6830
# Iteration 52600: Loss = 34.6766
# Iteration 52700: Loss = 34.6703
# Iteration 52800: Loss = 34.6640
# Iteration 52900: Loss = 34.6578
# Iteration 53000: Loss = 34.6516
# Iteration 53100: Loss = 34.6454
# Iteration 53200: Loss = 34.6392
# Iteration 53300: Loss = 34.6331
# Iteration 53400: Loss = 34.6270
# Iteration 53500: Loss = 34.6210
# Iteration 53600: Loss = 34.6149
# Iteration 53700: Loss = 34.6089
# Iteration 53800: Loss = 34.6030
# Iteration 53900: Loss = 34.5970
# Iteration 54000: Loss = 34.5911
# Iteration 54100: Loss = 34.5852
# Iteration 54200: Loss = 34.5794
# Iteration 54300: Loss = 34.5736
# Iteration 54400: Loss = 34.5678
# Iteration 54500: Loss = 34.5620
# Iteration 54600: Loss = 34.5563
# Iteration 54700: Loss = 34.5506
# Iteration 54800: Loss = 34.5449
# Iteration 54900: Loss = 34.5393
# Iteration 55000: Loss = 34.5336
# Iteration 55100: Loss = 34.5280
# Iteration 55200: Loss = 34.5225
# Iteration 55300: Loss = 34.5169
# Iteration 55400: Loss = 34.5114
# Iteration 55500: Loss = 34.5059
# Iteration 55600: Loss = 34.5005
# Iteration 55700: Loss = 34.4951
# Iteration 55800: Loss = 34.4896
# Iteration 55900: Loss = 34.4843
# Iteration 56000: Loss = 34.4789
# Iteration 56100: Loss = 34.4736
# Iteration 56200: Loss = 34.4683
# Iteration 56300: Loss = 34.4630
# Iteration 56400: Loss = 34.4578
# Iteration 56500: Loss = 34.4526
# Iteration 56600: Loss = 34.4474
# Iteration 56700: Loss = 34.4422
# Iteration 56800: Loss = 34.4370
# Iteration 56900: Loss = 34.4319
# Iteration 57000: Loss = 34.4268
# Iteration 57100: Loss = 34.4218
# Iteration 57200: Loss = 34.4167
# Iteration 57300: Loss = 34.4117
# Iteration 57400: Loss = 34.4067
# Iteration 57500: Loss = 34.4017
# Iteration 57600: Loss = 34.3968
# Iteration 57700: Loss = 34.3918
# Iteration 57800: Loss = 34.3869
# Iteration 57900: Loss = 34.3820
# Iteration 58000: Loss = 34.3772
# Iteration 58100: Loss = 34.3723
# Iteration 58200: Loss = 34.3675
# Iteration 58300: Loss = 34.3627
# Iteration 58400: Loss = 34.3580
# Iteration 58500: Loss = 34.3532
# Iteration 58600: Loss = 34.3485
# Iteration 58700: Loss = 34.3438
# Iteration 58800: Loss = 34.3391
# Iteration 58900: Loss = 34.3345
# Iteration 59000: Loss = 34.3299
# Iteration 59100: Loss = 34.3252
# Iteration 59200: Loss = 34.3207
# Iteration 59300: Loss = 34.3161
# Iteration 59400: Loss = 34.3115
# Iteration 59500: Loss = 34.3070
# Iteration 59600: Loss = 34.3025
# Iteration 59700: Loss = 34.2980
# Iteration 59800: Loss = 34.2936
# Iteration 59900: Loss = 34.2891
# Iteration 60000: Loss = 34.2847
# Iteration 60100: Loss = 34.2803
# Iteration 60200: Loss = 34.2759
# Iteration 60300: Loss = 34.2716
# Iteration 60400: Loss = 34.2672
# Iteration 60500: Loss = 34.2629
# Iteration 60600: Loss = 34.2586
# Iteration 60700: Loss = 34.2543
# Iteration 60800: Loss = 34.2501
# Iteration 60900: Loss = 34.2458
# Iteration 61000: Loss = 34.2416
# Iteration 61100: Loss = 34.2374
# Iteration 61200: Loss = 34.2332
# Iteration 61300: Loss = 34.2291
# Iteration 61400: Loss = 34.2249
# Iteration 61500: Loss = 34.2208
# Iteration 61600: Loss = 34.2167
# Iteration 61700: Loss = 34.2126
# Iteration 61800: Loss = 34.2085
# Iteration 61900: Loss = 34.2045
# Iteration 62000: Loss = 34.2004
# Iteration 62100: Loss = 34.1964
# Iteration 62200: Loss = 34.1924
# Iteration 62300: Loss = 34.1885
# Iteration 62400: Loss = 34.1845
# Iteration 62500: Loss = 34.1806
# Iteration 62600: Loss = 34.1766
# Iteration 62700: Loss = 34.1727
# Iteration 62800: Loss = 34.1688
# Iteration 62900: Loss = 34.1650
# Iteration 63000: Loss = 34.1611
# Iteration 63100: Loss = 34.1573
# Iteration 63200: Loss = 34.1534
# Iteration 63300: Loss = 34.1496
# Iteration 63400: Loss = 34.1458
# Iteration 63500: Loss = 34.1421
# Iteration 63600: Loss = 34.1383
# Iteration 63700: Loss = 34.1346
# Iteration 63800: Loss = 34.1309
# Iteration 63900: Loss = 34.1272
# Iteration 64000: Loss = 34.1235
# Iteration 64100: Loss = 34.1198
# Iteration 64200: Loss = 34.1161
# Iteration 64300: Loss = 34.1125
# Iteration 64400: Loss = 34.1089
# Iteration 64500: Loss = 34.1053
# Iteration 64600: Loss = 34.1017
# Iteration 64700: Loss = 34.0981
# Iteration 64800: Loss = 34.0945
# Iteration 64900: Loss = 34.0910
# Iteration 65000: Loss = 34.0875
# Iteration 65100: Loss = 34.0840
# Iteration 65200: Loss = 34.0805
# Iteration 65300: Loss = 34.0770
# Iteration 65400: Loss = 34.0735
# Iteration 65500: Loss = 34.0700
# Iteration 65600: Loss = 34.0666
# Iteration 65700: Loss = 34.0632
# Iteration 65800: Loss = 34.0598
# Iteration 65900: Loss = 34.0564
# Iteration 66000: Loss = 34.0530
# Iteration 66100: Loss = 34.0496
# Iteration 66200: Loss = 34.0463
# Iteration 66300: Loss = 34.0429
# Iteration 66400: Loss = 34.0396
# Iteration 66500: Loss = 34.0363
# Iteration 66600: Loss = 34.0330
# Iteration 66700: Loss = 34.0297
# Iteration 66800: Loss = 34.0265
# Iteration 66900: Loss = 34.0232
# Iteration 67000: Loss = 34.0200
# Iteration 67100: Loss = 34.0167
# Iteration 67200: Loss = 34.0135
# Iteration 67300: Loss = 34.0103
# Iteration 67400: Loss = 34.0071
# Iteration 67500: Loss = 34.0040
# Iteration 67600: Loss = 34.0008
# Iteration 67700: Loss = 33.9977
# Iteration 67800: Loss = 33.9945
# Iteration 67900: Loss = 33.9914
# Iteration 68000: Loss = 33.9883
# Iteration 68100: Loss = 33.9852
# Iteration 68200: Loss = 33.9821
# Iteration 68300: Loss = 33.9791
# Iteration 68400: Loss = 33.9760
# Iteration 68500: Loss = 33.9730
# Iteration 68600: Loss = 33.9699
# Iteration 68700: Loss = 33.9669
# Iteration 68800: Loss = 33.9639
# Iteration 68900: Loss = 33.9609
# Iteration 69000: Loss = 33.9579
# Iteration 69100: Loss = 33.9550
# Iteration 69200: Loss = 33.9520
# Iteration 69300: Loss = 33.9491
# Iteration 69400: Loss = 33.9461
# Iteration 69500: Loss = 33.9432
# Iteration 69600: Loss = 33.9403
# Iteration 69700: Loss = 33.9374
# Iteration 69800: Loss = 33.9345
# Iteration 69900: Loss = 33.9316
# Iteration 70000: Loss = 33.9288
# Iteration 70100: Loss = 33.9259
# Iteration 70200: Loss = 33.9231
# Iteration 70300: Loss = 33.9203
# Iteration 70400: Loss = 33.9174
# Iteration 70500: Loss = 33.9146
# Iteration 70600: Loss = 33.9118
# Iteration 70700: Loss = 33.9091
# Iteration 70800: Loss = 33.9063
# Iteration 70900: Loss = 33.9035
# Iteration 71000: Loss = 33.9008
# Iteration 71100: Loss = 33.8980
# Iteration 71200: Loss = 33.8953
# Iteration 71300: Loss = 33.8926
# Iteration 71400: Loss = 33.8899
# Iteration 71500: Loss = 33.8872
# Iteration 71600: Loss = 33.8845
# Iteration 71700: Loss = 33.8818
# Iteration 71800: Loss = 33.8792
# Iteration 71900: Loss = 33.8765
# Iteration 72000: Loss = 33.8739
# Iteration 72100: Loss = 33.8712
# Iteration 72200: Loss = 33.8686
# Iteration 72300: Loss = 33.8660
# Iteration 72400: Loss = 33.8634
# Iteration 72500: Loss = 33.8608
# Iteration 72600: Loss = 33.8582
# Iteration 72700: Loss = 33.8556
# Iteration 72800: Loss = 33.8531
# Iteration 72900: Loss = 33.8505
# Iteration 73000: Loss = 33.8480
# Iteration 73100: Loss = 33.8455
# Iteration 73200: Loss = 33.8429
# Iteration 73300: Loss = 33.8404
# Iteration 73400: Loss = 33.8379
# Iteration 73500: Loss = 33.8354
# Iteration 73600: Loss = 33.8329
# Iteration 73700: Loss = 33.8305
# Iteration 73800: Loss = 33.8280
# Iteration 73900: Loss = 33.8255
# Iteration 74000: Loss = 33.8231
# Iteration 74100: Loss = 33.8207
# Iteration 74200: Loss = 33.8182
# Iteration 74300: Loss = 33.8158
# Iteration 74400: Loss = 33.8134
# Iteration 74500: Loss = 33.8110
# Iteration 74600: Loss = 33.8086
# Iteration 74700: Loss = 33.8062
# Iteration 74800: Loss = 33.8039
# Iteration 74900: Loss = 33.8015
# Iteration 75000: Loss = 33.7991
# Iteration 75100: Loss = 33.7968
# Iteration 75200: Loss = 33.7945
# Iteration 75300: Loss = 33.7921
# Iteration 75400: Loss = 33.7898
# Iteration 75500: Loss = 33.7875
# Iteration 75600: Loss = 33.7852
# Iteration 75700: Loss = 33.7829
# Iteration 75800: Loss = 33.7806
# Iteration 75900: Loss = 33.7783
# Iteration 76000: Loss = 33.7761
# Iteration 76100: Loss = 33.7738
# Iteration 76200: Loss = 33.7715
# Iteration 76300: Loss = 33.7693
# Iteration 76400: Loss = 33.7671
# Iteration 76500: Loss = 33.7648
# Iteration 76600: Loss = 33.7626
# Iteration 76700: Loss = 33.7604
# Iteration 76800: Loss = 33.7582
# Iteration 76900: Loss = 33.7560
# Iteration 77000: Loss = 33.7538
# Iteration 77100: Loss = 33.7516
# Iteration 77200: Loss = 33.7495
# Iteration 77300: Loss = 33.7473
# Iteration 77400: Loss = 33.7451
# Iteration 77500: Loss = 33.7430
# Iteration 77600: Loss = 33.7409
# Iteration 77700: Loss = 33.7387
# Iteration 77800: Loss = 33.7366
# Iteration 77900: Loss = 33.7345
# Iteration 78000: Loss = 33.7324
# Iteration 78100: Loss = 33.7303
# Iteration 78200: Loss = 33.7282
# Iteration 78300: Loss = 33.7261
# Iteration 78400: Loss = 33.7240
# Iteration 78500: Loss = 33.7219
# Iteration 78600: Loss = 33.7199
# Iteration 78700: Loss = 33.7178
# Iteration 78800: Loss = 33.7157
# Iteration 78900: Loss = 33.7137
# Iteration 79000: Loss = 33.7117
# Iteration 79100: Loss = 33.7096
# Iteration 79200: Loss = 33.7076
# Iteration 79300: Loss = 33.7056
# Iteration 79400: Loss = 33.7036
# Iteration 79500: Loss = 33.7016
# Iteration 79600: Loss = 33.6996
# Iteration 79700: Loss = 33.6976
# Iteration 79800: Loss = 33.6956
# Iteration 79900: Loss = 33.6936
# Iteration 80000: Loss = 33.6917
# Iteration 80100: Loss = 33.6897
# Iteration 80200: Loss = 33.6878
# Iteration 80300: Loss = 33.6858
# Iteration 80400: Loss = 33.6839
# Iteration 80500: Loss = 33.6819
# Iteration 80600: Loss = 33.6800
# Iteration 80700: Loss = 33.6781
# Iteration 80800: Loss = 33.6762
# Iteration 80900: Loss = 33.6743
# Iteration 81000: Loss = 33.6724
# Iteration 81100: Loss = 33.6705
# Iteration 81200: Loss = 33.6686
# Iteration 81300: Loss = 33.6667
# Iteration 81400: Loss = 33.6648
# Iteration 81500: Loss = 33.6630
# Iteration 81600: Loss = 33.6611
# Iteration 81700: Loss = 33.6593
# Iteration 81800: Loss = 33.6574
# Iteration 81900: Loss = 33.6556
# Iteration 82000: Loss = 33.6537
# Iteration 82100: Loss = 33.6519
# Iteration 82200: Loss = 33.6501
# Iteration 82300: Loss = 33.6482
# Iteration 82400: Loss = 33.6464
# Iteration 82500: Loss = 33.6446
# Iteration 82600: Loss = 33.6428
# Iteration 82700: Loss = 33.6410
# Iteration 82800: Loss = 33.6392
# Iteration 82900: Loss = 33.6375
# Iteration 83000: Loss = 33.6357
# Iteration 83100: Loss = 33.6339
# Iteration 83200: Loss = 33.6321
# Iteration 83300: Loss = 33.6304
# Iteration 83400: Loss = 33.6286
# Iteration 83500: Loss = 33.6269
# Iteration 83600: Loss = 33.6251
# Iteration 83700: Loss = 33.6234
# Iteration 83800: Loss = 33.6217
# Iteration 83900: Loss = 33.6199
# Iteration 84000: Loss = 33.6182
# Iteration 84100: Loss = 33.6165
# Iteration 84200: Loss = 33.6148
# Iteration 84300: Loss = 33.6131
# Iteration 84400: Loss = 33.6114
# Iteration 84500: Loss = 33.6097
# Iteration 84600: Loss = 33.6080
# Iteration 84700: Loss = 33.6063
# Iteration 84800: Loss = 33.6047
# Iteration 84900: Loss = 33.6030
# Iteration 85000: Loss = 33.6013
# Iteration 85100: Loss = 33.5997
# Iteration 85200: Loss = 33.5980
# Iteration 85300: Loss = 33.5964
# Iteration 85400: Loss = 33.5947
# Iteration 85500: Loss = 33.5931
# Iteration 85600: Loss = 33.5914
# Iteration 85700: Loss = 33.5898
# Iteration 85800: Loss = 33.5882
# Iteration 85900: Loss = 33.5866
# Iteration 86000: Loss = 33.5850
# Iteration 86100: Loss = 33.5833
# Iteration 86200: Loss = 33.5817
# Iteration 86300: Loss = 33.5801
# Iteration 86400: Loss = 33.5785
# Iteration 86500: Loss = 33.5770
# Iteration 86600: Loss = 33.5754
# Iteration 86700: Loss = 33.5738
# Iteration 86800: Loss = 33.5722
# Iteration 86900: Loss = 33.5707
# Iteration 87000: Loss = 33.5691
# Iteration 87100: Loss = 33.5675
# Iteration 87200: Loss = 33.5660
# Iteration 87300: Loss = 33.5644
# Iteration 87400: Loss = 33.5629
# Iteration 87500: Loss = 33.5613
# Iteration 87600: Loss = 33.5598
# Iteration 87700: Loss = 33.5583
# Iteration 87800: Loss = 33.5567
# Iteration 87900: Loss = 33.5552
# Iteration 88000: Loss = 33.5537
# Iteration 88100: Loss = 33.5522
# Iteration 88200: Loss = 33.5507
# Iteration 88300: Loss = 33.5492
# Iteration 88400: Loss = 33.5477
# Iteration 88500: Loss = 33.5462
# Iteration 88600: Loss = 33.5447
# Iteration 88700: Loss = 33.5432
# Iteration 88800: Loss = 33.5417
# Iteration 88900: Loss = 33.5403
# Iteration 89000: Loss = 33.5388
# Iteration 89100: Loss = 33.5373
# Iteration 89200: Loss = 33.5359
# Iteration 89300: Loss = 33.5344
# Iteration 89400: Loss = 33.5329
# Iteration 89500: Loss = 33.5315
# Iteration 89600: Loss = 33.5300
# Iteration 89700: Loss = 33.5286
# Iteration 89800: Loss = 33.5272
# Iteration 89900: Loss = 33.5257
# Iteration 90000: Loss = 33.5243
# Iteration 90100: Loss = 33.5229
# Iteration 90200: Loss = 33.5215
# Iteration 90300: Loss = 33.5200
# Iteration 90400: Loss = 33.5186
# Iteration 90500: Loss = 33.5172
# Iteration 90600: Loss = 33.5158
# Iteration 90700: Loss = 33.5144
# Iteration 90800: Loss = 33.5130
# Iteration 90900: Loss = 33.5116
# Iteration 91000: Loss = 33.5102
# Iteration 91100: Loss = 33.5089
# Iteration 91200: Loss = 33.5075
# Iteration 91300: Loss = 33.5061
# Iteration 91400: Loss = 33.5047
# Iteration 91500: Loss = 33.5034
# Iteration 91600: Loss = 33.5020
# Iteration 91700: Loss = 33.5006
# Iteration 91800: Loss = 33.4993
# Iteration 91900: Loss = 33.4979
# Iteration 92000: Loss = 33.4966
# Iteration 92100: Loss = 33.4952
# Iteration 92200: Loss = 33.4939
# Iteration 92300: Loss = 33.4925
# Iteration 92400: Loss = 33.4912
# Iteration 92500: Loss = 33.4899
# Iteration 92600: Loss = 33.4886
# Iteration 92700: Loss = 33.4872
# Iteration 92800: Loss = 33.4859
# Iteration 92900: Loss = 33.4846
# Iteration 93000: Loss = 33.4833
# Iteration 93100: Loss = 33.4820
# Iteration 93200: Loss = 33.4807
# Iteration 93300: Loss = 33.4794
# Iteration 93400: Loss = 33.4781
# Iteration 93500: Loss = 33.4768
# Iteration 93600: Loss = 33.4755
# Iteration 93700: Loss = 33.4742
# Iteration 93800: Loss = 33.4729
# Iteration 93900: Loss = 33.4716
# Iteration 94000: Loss = 33.4704
# Iteration 94100: Loss = 33.4691
# Iteration 94200: Loss = 33.4678
# Iteration 94300: Loss = 33.4666
# Iteration 94400: Loss = 33.4653
# Iteration 94500: Loss = 33.4640
# Iteration 94600: Loss = 33.4628
# Iteration 94700: Loss = 33.4615
# Iteration 94800: Loss = 33.4603
# Iteration 94900: Loss = 33.4590
# Iteration 95000: Loss = 33.4578
# Iteration 95100: Loss = 33.4566
# Iteration 95200: Loss = 33.4553
# Iteration 95300: Loss = 33.4541
# Iteration 95400: Loss = 33.4529
# Iteration 95500: Loss = 33.4516
# Iteration 95600: Loss = 33.4504
# Iteration 95700: Loss = 33.4492
# Iteration 95800: Loss = 33.4480
# Iteration 95900: Loss = 33.4468
# Iteration 96000: Loss = 33.4456
# Iteration 96100: Loss = 33.4444
# Iteration 96200: Loss = 33.4431
# Iteration 96300: Loss = 33.4419
# Iteration 96400: Loss = 33.4408
# Iteration 96500: Loss = 33.4396
# Iteration 96600: Loss = 33.4384
# Iteration 96700: Loss = 33.4372
# Iteration 96800: Loss = 33.4360
# Iteration 96900: Loss = 33.4348
# Iteration 97000: Loss = 33.4336
# Iteration 97100: Loss = 33.4325
# Iteration 97200: Loss = 33.4313
# Iteration 97300: Loss = 33.4301
# Iteration 97400: Loss = 33.4290
# Iteration 97500: Loss = 33.4278
# Iteration 97600: Loss = 33.4266
# Iteration 97700: Loss = 33.4255
# Iteration 97800: Loss = 33.4243
# Iteration 97900: Loss = 33.4232
# Iteration 98000: Loss = 33.4220
# Iteration 98100: Loss = 33.4209
# Iteration 98200: Loss = 33.4197
# Iteration 98300: Loss = 33.4186
# Iteration 98400: Loss = 33.4175
# Iteration 98500: Loss = 33.4163
# Iteration 98600: Loss = 33.4152
# Iteration 98700: Loss = 33.4141
# Iteration 98800: Loss = 33.4129
# Iteration 98900: Loss = 33.4118
# Iteration 99000: Loss = 33.4107
# Iteration 99100: Loss = 33.4096
# Iteration 99200: Loss = 33.4085
# Iteration 99300: Loss = 33.4074
# Iteration 99400: Loss = 33.4063
# Iteration 99500: Loss = 33.4052
# Iteration 99600: Loss = 33.4040
# Iteration 99700: Loss = 33.4030
# Iteration 99800: Loss = 33.4019
# Iteration 99900: Loss = 33.4008
# Updated w:  [[  4.53560372  -9.59405385 -11.82309649  14.61777164  15.47131491
#    16.20124499]]
# Updated b:  17.94941805024817
# Train Error:  33.39967792513611 , Test Error:  62.61231076356401

# %% [markdown]
# ## Part 2: Logistic Regression
#
# ### Problem Statement
# A Food grain industry requires an efficient classification system to help in sorting food grain species. You have to develop a Logistic Regression model for this purpose.
#  Given various features of a rice grain such as area, perimeter, axis lengths etc. as input features, the task is to build a logistic regression model to predict the species of the food grain.
#
# ### Dataset Description
#
# **For Even Roll Number Students**
#
# Dataset Filename: Rice_Classification.csv
#
# Attribute Information:
# + Area: Returns the number of pixels within the boundaries of the rice grain.
# + Perimeter: Calculates the circumference by calculating the distance between pixels around the boundaries of the rice grain.
# + Major Axis Length: The longest line that can be drawn on the rice grain, i.e. the main axis distance, gives.
# + Minor Axis Length: The shortest line that can be drawn on the rice grain, i.e. the small axis distance, gives.
# + Eccentricity: It measures how round the ellipse, which has the same moments as the rice grain, is.
# + Convex Area: Returns the pixel count of the smallest convex shell of the region formed by the rice grain.
# + Extent: Returns the ratio of the region formed by the rice grain to the bounding box pixels.
#
# Target Variable: Class: Cammeo and Osmancik
#
# **For Odd Roll Number Students**
#
# Dataset Filename: Pumpkin_Seeds_Dataset.csv
#
# Attribute Information:
#
# + Area: Represents the number of pixels within the boundaries of the pumpkin seed.
#
# + Perimeter: Calculates the circumference by measuring the distance between pixels around the boundary of the pumpkin seed.
#
# + Major Axis Length: The longest line that can be drawn on the pumpkin seed, representing the main axis distance.
#
# + Minor Axis Length: The shortest line that can be drawn on the pumpkin seed, representing the minor axis distance.
#
# + Convex Area: Returns the pixel count of the smallest convex shell that can contain the pumpkin seed.
#
# + Equivalent Diameter: Diameter of a circle with the same area as the pumpkin seed.
#
# + Eccentricity: This measures how round the ellipse, which has the same moments as the pumpkin seed has.
#
# + Solidity: This is the ratio of the area of the pumpkin seed to the area of its convex hull. It measures the extent to which the shape is convex.
#
# + Extent: Returns the ratio of the area of the pumpkin seed to the area of its bounding box.
#
# + Roundness: Measure of how closely the shape of the pumpkin seed approaches that of a circle.
#
# + Aspect Ratio: Ratio of the major axis length to the minor axis length.
#
# + Compactness: Measure of the shape's compactness, which is the shape's deviation from being a perfect circle. In essence, compactness quantifies how efficiently an object's area is packed within its perimeter.
#
# Target Variable: Class: Çerçevelik and Ürgüp Sivrisi
#
#
#
# These are the following steps or functions that you have to complete to create and train the linear regression model:
# 1. Reading the data
# 2. Creating the sigmoid function
# 2. Computing the loss function
# 3. Computing the gradient of the loss
# 4. Training the model using Batch Gradient Descent

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (1.14.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from scipy) (2.0.1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import logsumexp
import copy
import math

# %% [markdown]
# ### 2.1. Reading the data
#
# In the function ```load_data```, you have to read data from the file, store it in a dataframe and split the data from the dataframe into two numpy arrays X and y.
#
# **X** : data of the input features
#
# **y**  : data of the class labels
#
# The class labels in **y** should be replaced with '0' and '1', for corresponding classes.

# %%
## CODE REQUIRED ##

def load_data(filepath):
    """
    This function loads the data into a pandas dataframe and converts it into X and y numpy arrays
    y should be a binary numpy array with values 0 and 1, for 2 different classes
    Args:
        filepath: File path as a string
    Returns:
        X: Input data of the shape (# of samples, # of input features)
        y: Target variable of the shape (# of sample,) with values 0 and 1, for 2 different classes
    """

    ### START CODE HERE ###
    X= filepath.iloc[:,:-1].values #All rows and all columns except the last column
    y= filepath.iloc[:,-1].values #Only the last column is selected



    ### END CODE HERE ###

    return X,y

filepath = None
### START CODE HERE ###
## set the file path
import pandas as pd
filepath=pd.read_csv(r"C:\Users\HP\Downloads\ML_Assignment_1\ML_Assignment_1\Rice_Classification.csv")

### END CODE HERE ###

X, y = load_data(filepath)

print("Shape of X: ",X.shape, "Shape of y: ",y.shape)
# Out:
# Shape of X:  (3810, 7) Shape of y:  (3810,)

# %% [markdown]
# We will not use all the features from X.
#
# For Even Roll Number Students: Set the last two digits of your roll number as the random seed and pick a number r between 4 and 7 (both inclusive) randomly. Use the first r features of the numpy array X.
#
# For Odd Roll Number Students: Set the last two digits of your roll number as the random seed and pick a number r between 8 and 12 (both inclusive) randomly. Use the first r features of the numpy array X.

# %%
## CODE REQUIRED ##

def random_feature_selection(X):
    """

    Args:
        X: Input data of the shape (# of samples, # of input features)
    Returns:
        X_new: New input data of the shape (# of samples, r) containg only the first r features from X
    """

    X_new = None

    ### START CODE HERE ###
    r = 5 # Select first 5 features
    X_new = X[:,:r] # Select all rows and first r columns



    ### END CODE HERE ###

    return X_new

X = random_feature_selection(X)
print("Shape of X: ",X.shape, "Shape of y: ",y.shape)
# Out:
# Shape of X:  (3810, 5) Shape of y:  (3810,)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\envs\cs60050\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We need to pre-process the data. We are using min-max scaler to scale the input data ($X$).
#
# After that, we split the data (```X``` and ```y```) into a training dataset (```X_train``` and ```y_train```) and test dataset (```X_test``` and ```y_test```)

# %%
## Data scaling and train-test split

def train_test_split(X, y, test_size=0.25, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    split_index = int(X.shape[0] * (1 - test_size))

    train_indices = indices[:split_index]
    test_indices = indices[split_index:]

    X_train = X[train_indices]
    X_test = X[test_indices]
    y_train = y[train_indices]
    y_test = y[test_indices]

    return X_train, X_test, y_train, y_test

def min_max_scaler(X, feature_range=(0, 1)):
    X_min = np.min(X, axis=0)
    X_max = np.max(X, axis=0)

    X_scaled = (X-X_min)/(X_max-X_min)

    return X_scaled
# Convert categorical target variable to numeric
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# Feature normalization
X = min_max_scaler(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print("Shape of X_train: ",X_train.shape, "Shape of y_train: ",y_train.shape)
print("Shape of X_test: ",X_test.shape, "Shape of y_test: ",y_test.shape)
# Out:
# Shape of X_train:  (2857, 5) Shape of y_train:  (2857,)
# Shape of X_test:  (953, 5) Shape of y_test:  (953,)

# %% [markdown]
# ### 2.2. Creating the Sigmoid Function
# Recall that for logistic regression, the model is represented as
#
# $$ f_{\mathbf{w},b}(x) = g(\mathbf{w}\cdot \mathbf{x} + b)$$
# where function $g$ is the sigmoid function. The sigmoid function is defined as:
#
# $$g(z) = \frac{1}{1+e^{-z}}$$
#
#
# The function below returns the value of the sigmoid function for an input numpy array z. If the numpy array 'z' stores multiple numbers, we'd like to apply the sigmoid function to each value in the input array

# %%
## CODE REQUIRED ##

def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z: A scalar or numpy array of any size.

    Returns:
        g: sigmoid(z)
    """
    g = None
    z = z.astype(float)
    ### START CODE HERE ###
    g = 1/(1 + np.exp(-z))



    ### END SOLUTION ###

    return g

# %% [markdown]
# ### 2.3. Computing the loss Function
#
# Recall that for logistic regression, the cost function is of the form
#
# $$ J(\mathbf{w},b) = \frac{1}{m}\sum_{i=0}^{m-1} \left[ loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) \right] \tag{1}$$
#
# where
# * m is the number of training examples in the dataset
#
#
# * $loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)})$ is the cost for a single data point, which is -
#
#     $$loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) = (-y^{(i)} \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) - \left( 1 - y^{(i)}\right) \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) \tag{2}$$
#
#
# *  $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ is the model's prediction, while $y^{(i)}$, which is the actual label
#
# *  $f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = g(\mathbf{w} \cdot \mathbf{x^{(i)}} + b)$ where function $g$ is the sigmoid function.
#
# Please complete the function loss_function that takes
#
#  **X**  (input features)
#
#  **y**  (class labels)
#
#  **w**  (Parameters of the logistic regression model, (excluding the bias), a numpy array of the shape(1, number of features))
#
#  **b**  (Bias value of the logistic regression model)
#
#  You can use the Sigmoid function that you implemented above.

# %%
## CODE REQUIRED ##

def loss_function(X, y, w, b):
 """
 Computes the loss function for all the training examples
 Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w: Parameters of the logistic regression model (excluding the bias) of the shape (1, number of features)
        b: Bias parameter (scalar) of the logistic regression model

  Returns:
        total_cost: The loss function value of using w and b as the parameters to fit the data points in X and y

 """
 m, n = X.shape

 total_cost = 0
 ### START CODE HERE ###
 for i in range(m):
     z = np.dot(w,X[i,:]) + b
     h = sigmoid(z)
     total_cost += (-y[i] * np.log(h)) - (1 - y[i]) * np.log(1 - h)

 total_cost /= m

 ### END CODE HERE ###

 return total_cost

# %% [markdown]
# ### 2.4. Computing the Gradient of the Loss
#
# Recall that the gradient descent algorithm is:
#
# $$\begin{align*}& \text{repeat until convergence:} \; \lbrace \newline \; & b := b -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial b} \newline       \; & w_j := w_j -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial w_j} \tag{1}  \; & \text{for j := 0..n-1}\newline & \rbrace\end{align*}$$
#
# where, parameters $b$, $w_j$ are all updated simultaniously
#
# In this step, you are required to complete the `compute_gradient_logistic_regression` function to compute $\frac{\partial J(\mathbf{w},b)}{\partial w}$, $\frac{\partial J(\mathbf{w},b)}{\partial b}$ from equations (2) and (3) below.
#
# $$
# \frac{\partial J(\mathbf{w},b)}{\partial b}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - \mathbf{y}^{(i)}) \tag{2}
# $$
# $$
# \frac{\partial J(\mathbf{w},b)}{\partial w_j}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - \mathbf{y}^{(i)})x_{j}^{(i)} \tag{3}
# $$
# * m is the number of training examples in the dataset
#
#
# *  $f_{\mathbf{w},b}(x^{(i)})$ is the model's prediction, while $y^{(i)}$ is the actual label
#
# You can use the sigmoid function that you implemented above.

# %%
## CODE REQUIRED ##

def compute_gradient_logistic_regression(X, y, w, b):
    """
    Computes the gradient values of the loss function
    Args:
       X: Input data of the shape (# of training samples, # of input features)
       y: Target variable of the shape (# of training sample,)
       w: Parameters of the logistic regression model (excluding the bias) of the shape (1, number of features)
       b: Bias parameter of the logistic regression model of the shape (1,1) or a scaler
    Returns:
       dL_dw : The gradient of the cost w.r.t. the parameters w with shape same as w
       dL_db : The gradient of the cost w.r.t. the parameter b with shape same as b
    """
    m, n = X.shape
    dj_dw = np.zeros(w.shape)
    dj_db = 0

    ### START CODE HERE ###
    dj_dw = np.zeros_like(w)  # Initialize the gradient for w
    dj_db = 0  # Initialize the gradient for b

    for i in range(m):
        z = np.dot(w, X[i, :]) + b  # Dot product between w and X[i, :]
        h = sigmoid(z)  # Compute the sigmoid of z
        # Compute gradients and accumulate them
        dj_dw += (h - y[i]) * X[i, :]  # This will have the same shape as w
        dj_db += (h - y[i])  # This is a scalar

# Average the gradients over all training examples
    dj_dw = dj_dw / m
    dj_db = dj_db / m


    ### END CODE HERE ###


    return dj_db, dj_dw

# %% [markdown]
# ### 2.5. Training the model using Batch Gradient Descent
#
# Please complete the batch gradient descent algorithm for logistic regression to train and learn the parameters of the logistic regression model. You have to use ```loss_function``` and ```compute_gradient_logistic regression``` functions that you have implemented earlier in this assignment.
#
# In this ```batch_gradient_descent_logistic_regression``` function, you have to compute the gradient for the training samples and update the parameters $w$ and $b$ in every iteration:
#
# + $w \leftarrow w - \alpha \frac{\partial L}{\partial w}$
#
# + $b \leftarrow b - \alpha \frac{\partial L}{\partial b}$
#
# This function takes   ```X```    (input features),  ```y```  (class labels),  ```w_in```  (intial values of parameters(excluding bias)),  ```b_in```  (initial value for bias),  ```num_iters```   (number of iterations of training) as input.
#
# Additionally, you have compute the loss function values in every iteration and store it in the list variable ```loss_hist``` and print the loss value after every 100 iterations during the training process.

# %%
## CODE REQUIRED ##

def batch_gradient_descent_logistic_regression(X, y, w_in, b_in, alpha, num_iters):
    """
    Batch gradient descent to learn the parameters (w and b) of the linear regression model and to print loss values
    every 100 iterations

    Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w_in: Initial parameters of the logistic regression model (excluding the bias) of the shape (1, number of features)
        b_in: Initial bias parameter (scalar) of the logistic regression model
        alpha: Learning rate
        num_iters: number of iterations
    Returns
        w: Updated values of parameters of the model after training
        b: Updated bias of the model after training
        loss_hist: List of loss values for every iteration
    """

    # number of training examples
    m = len(X)

    # list to store the loss values for every iterations
    loss_hist = []

    ### START CODE HERE ###
    w = copy.deepcopy(w_in) # Avoid modifying w_in
    b = b_in

    for i in range(num_iters):
        # Calculate the gradient and update parameters
        dj_db, dj_dw = compute_gradient_logistic_regression(X, y, w, b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        # Calculate loss and append it to the list
        loss = loss_function(X, y, w, b)
        loss_hist.append(loss)

        # Print loss every 100 iterations
        if (i%100 == 0):
            print("Loss function value at iteration %i: %f" % (i, loss.item()))


    ### END CODE HERE ###

    return w_in, b_in, loss_hist

# %% [markdown]
# Now you have to intialize the model parameters ($w$ and $b$) and learning rate (```alpha```). The learning rate ```alpha``` has to be randomly initialized between 0.01 and 0.09. To randomly initialize the learning rate, you have to first set the last two digits of your roll number as the random seed using ```random.seed()``` function.

# %%
## CODE REQUIRED ##

## set the last two digits of your roll number as the random seed
random_seed = None
### START CODE HERE ###
random_seed = 28
### END CODE HERE ###
np.random.seed(random_seed)

def initialize_parameters():
    """
    This function randomly initializes the model parameters (w and b) and the hyperparameter alpha
    Initial w and b should be randomly sampled from a normal distribution with mean 0
    alpha should be randomly initialized between 0.01 and 0.09 by using last two digits of your roll number as the random seed
    Args:
        None
    Returns:
        initial_w: Initial parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        initial_b: Initial bias parameter (scalar) of the linear regression model
        alpha: Learning rate
    """

    initial_w = None
    initial_b = None
    alpha = None

    ### START CODE HERE ###
    initial_w = np.random.randn(1, X_train.shape[1])  # Random weights
    initial_b = np.random.randn(1)  # Random bias
    np.random.seed(random_seed)  # Use your roll number's last two digits as seed
    alpha = 0.05  

    ### END CODE HERE ###

    return initial_w,initial_b,alpha

# %% [markdown]
# The following cell runs the batch gradient algorithm for
# ```num_iterations=1000``` to train the logistic regression model. You can change the number of iterations to check any improvements in the performance

# %%
# initialize the parameters (w and b) randomly
# Encode the labels
y_train = np.where(y_train == 'Cammeo', 0, 1).astype(float)
y_test = np.where(y_test == 'Cammeo', 0, 1).astype(float)


initial_w, initial_b, alpha = initialize_parameters()
num_iterations = 1000

w, b, loss_hist = batch_gradient_descent_logistic_regression(X_train ,y_train, initial_w, initial_b, alpha, num_iterations)
print("optimized parameter values w:", w)
print("optimized parameter value b:", b)
# Out:
# Loss function value at iteration 0: 0.137475
# Loss function value at iteration 100: 0.057515
# Loss function value at iteration 200: 0.036139
# Loss function value at iteration 300: 0.026335
# Loss function value at iteration 400: 0.020720
# Loss function value at iteration 500: 0.017085
# Loss function value at iteration 600: 0.014539
# Loss function value at iteration 700: 0.012656
# Loss function value at iteration 800: 0.011208
# Loss function value at iteration 900: 0.010059
# optimized parameter values w: [[ 0.44633238  1.66912005 -0.26427996 -0.96783493  0.05918843]]
# optimized parameter value b: [1.51461999]

# %% [markdown]
# ### 2.6. Final Train and Test Accuracy
# After the logistic regression model is trained, we will predict the class labels for the training set and test set and we will compute the accuracy.
#
# Please complete the `predict` function to produce `1` or `0` predictions given a dataset and a learned parameter vector $w$ and $b$.
# - First you need to compute the prediction from the model $f(x^{(i)}) = g(w \cdot x^{(i)})$ for every example
#
# - We interpret the output of the model ($f(x^{(i)})$) as the probability that $y^{(i)}=1$ given $x^{(i)}$ and parameterized by $w$.
# - Therefore, to get a final prediction ($y^{(i)}=0$ or $y^{(i)}=1$) from the logistic regression model, you can use the following heuristic -
#
#   if $f(x^{(i)}) >= 0.5$, predict $y^{(i)}=1$
#
#   if $f(x^{(i)}) < 0.5$, predict $y^{(i)}=0$

# %%
def predict(X, w, b):
      """
      Predict whether the label is 0 or 1 using learned logistic regression parameters (w,b)

      Args:
        X: Input data of shape (number of sample, number of features)
        w: Parameters of the logistic regression model (excluding the bias) of the shape (1, number of features)
        b: Bias parameter of the logistic regression model

      Returns:
        p: Predictions for X using a threshold at 0.5
      """
      m, n = X.shape
      p = np.zeros(m)
      ### START CODE HERE###
     # Compute the linear combination z = w * X + b
      z = np.dot(X, w.T) + b
    
    # Apply the sigmoid function to get probabilities
      prob = sigmoid(z)
    
    # Convert probabilities to binary predictions (0 or 1)
      p = (prob >= 0.5).astype(int)


      ### END CODE HERE ###
      return p

# %% [markdown]
# Now let's use this to compute the accuracy on the training and test datasets

# %%
p_train = predict(X_train, w,b)
print('Train Accuracy: %f'%(np.mean(p_train == y_train) * 100))
p_test = predict(X_test, w,b)
print('Test Accuracy: %f'%(np.mean(p_test == y_test) * 100))
# Out:
# Train Accuracy: 100.000000
# Test Accuracy: 100.000000

# %% [markdown]
# Now, we plot the loss function values for every iteration.

# %%
# PLotting the loss values for every training iterations

loss_plot = loss_hist#[loss_hist[i][0][0] for i in range(len(loss_hist))]
plt.xlabel("Iterations")
plt.ylabel("Loss function")
plt.plot(loss_plot)
plt.show()

# %% [markdown]
# ### 2.7 Experimenting with different values of the Hyperparemeters
#
# Previously, we randomly sampled the learning rate and the number of features to train the model. Now, you have to manually choose the number of features and the learning rate. Then, you have to train the model again on the manually choosen hyperparameters (number of features and learning rate). In the next cell, you have to manually choose the hyperparameters and write the code to train the model.
#
# After the model is trained, you have to compare the performance of the model with random chosen hyperparameters and the model **with** manually chosen hyperparameters.

# %%
# Manually chosen hyperparameters
manual_alpha = 0.01  # Learning rate
manual_num_features = X_train.shape[1]  # Number of features
manual_initial_w = np.random.randn(1, manual_num_features) * 0.01  # Initial weights
manual_initial_b = np.random.randn() * 0.01  # Initial bias
manual_num_iterations = 1000  # Number of iterations

# Train the model using manually chosen hyperparameters
manual_w, manual_b, manual_loss_hist = batch_gradient_descent_logistic_regression(
    X_train, y_train, manual_initial_w, manual_initial_b, manual_alpha, manual_num_iterations
)

# Predict using the manually trained model
manual_predictions = predict(X_test, manual_w, manual_b)

# Calculate accuracy
manual_accuracy = np.mean(manual_predictions == y_test)
print("Manually chosen hyperparameters model accuracy:", manual_accuracy*100)


# Plot the loss history for manual hyperparameters
import matplotlib.pyplot as plt

plt.plot(range(manual_num_iterations), manual_loss_hist, label="Manual Hyperparameters")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.show()
# Out:
# Loss function value at iteration 0: 0.677676
# Loss function value at iteration 100: 0.335038
# Loss function value at iteration 200: 0.209616
# Loss function value at iteration 300: 0.149791
# Loss function value at iteration 400: 0.115727
# Loss function value at iteration 500: 0.093987
# Loss function value at iteration 600: 0.078995
# Loss function value at iteration 700: 0.068067
# Loss function value at iteration 800: 0.059764
# Loss function value at iteration 900: 0.053249
# Manually chosen hyperparameters model accuracy: 100.0
